# %% [markdown]
# # eval DB viewer
#
# Read-only look at the two shared SQLite DBs.
#
# - **records (ops DB)** `easyads_ops.db` — jobs / node_executions / llm_calls / schema_validations / job_cost_summary / dirty_field_events
# - **eval DB** `easyads_eval.db` — eval_runs / score_items / gate_results / domain_scores / judge_status
#
# Run the **Setup** cell first, then any cell below. Re-run a cell to refresh (safe to run while `make eval-sample` is generating).
#
# **Validity rule:** a job is real only if every `llm_calls.fallback_used = 0` AND `t2i_engine = gpt_image_2` AND `imgs >= 1`. Any `fallback_used = 1` -> discard that job.

# %% [markdown]
# ## Setup

# %%
import os, sqlite3

# polars(빠른 Rust DataFrame)로 표시. 미설치 환경(호스트 .venv 등)에선 stdlib _Table 폴백 →
# 노트북이 어디서든 hard-fail 안 함. 컨테이너(Dockerfile.eval)엔 polars 포함.
try:
    import polars as pl
    pl.Config.set_tbl_rows(-1)
    pl.Config.set_tbl_cols(-1)
    pl.Config.set_tbl_width_chars(10000)
    pl.Config.set_fmt_str_lengths(150)
    _HAVE_POLARS = True
except ModuleNotFoundError:
    _HAVE_POLARS = False


class _Table:
    """polars 미설치용 경량 폴백 — q()와 동일 인터페이스([r, c] 인덱싱, len) 유지해
    아래 셀들의 df[0, 0] / len(df) 가 polars 유무와 무관하게 동작."""
    def __init__(self, columns, rows):
        self.columns, self.rows = columns, rows
    def __len__(self):
        return len(self.rows)
    def __getitem__(self, key):
        if isinstance(key, tuple):
            r, c = key
            return self.rows[r][c]
        return self.rows[key]
    def __repr__(self):
        if not self.rows:
            return " | ".join(self.columns) + "\n(0 rows)"
        w = [max([len(str(c))] + [len(str(r[i])) for r in self.rows]) for i, c in enumerate(self.columns)]
        head = " | ".join(str(c).ljust(w[i]) for i, c in enumerate(self.columns))
        sep = "-+-".join("-" * x for x in w)
        body = "\n".join(" | ".join(str(v).ljust(w[i]) for i, v in enumerate(r)) for r in self.rows)
        return f"{head}\n{sep}\n{body}"


# /home/records on host, /app/records inside a container. Override with RECORDS_DIR.
RECORDS = os.environ.get('RECORDS_DIR') or next(
    (p for p in ('/home/records', '/app/records') if os.path.isdir(p)), '/home/records')
OPS_DB  = os.path.join(RECORDS, 'easyads_ops.db')
EVAL_DB = os.path.join(RECORDS, 'easyads_eval.db')


def q(db, sql, params=()):
    """읽기전용 쿼리 실행 → polars DataFrame(있으면) 또는 _Table 폴백."""
    with sqlite3.connect(db) as c:
        cur = c.execute(sql, params)
        rows = [tuple(r) for r in cur.fetchall()]
        cols = [d[0] for d in cur.description]
    if _HAVE_POLARS:
        return pl.DataFrame(rows, schema=cols, orient="row") if rows else pl.DataFrame(schema=cols)
    return _Table(cols, rows)


print('polars  :', 'yes' if _HAVE_POLARS else 'NO (stdlib fallback)')
print('RECORDS :', RECORDS)
print('OPS_DB  :', OPS_DB,  '(exists)' if os.path.isfile(OPS_DB)  else '(MISSING)')
print('EVAL_DB :', EVAL_DB, '(exists)' if os.path.isfile(EVAL_DB) else '(MISSING)')
# Out:
# polars  : yes
# RECORDS : /app/records
# OPS_DB  : /app/records/easyads_ops.db (exists)
# EVAL_DB : /app/records/easyads_eval.db (exists)

# %%
os.getcwd()
# Out:
# '/app/orchestrator/eval'

# %% [markdown]
# # records (ops DB)

# %% [markdown]
# ### jobs — overview (newest first)

# %%
q(OPS_DB, '''
  SELECT job_id, user_plan AS plan, render_profile AS render, status,
         entry_mode, revision, created_at
  FROM jobs ORDER BY created_at DESC LIMIT 30
''')
# Out:
# shape: (14, 7)
# ┌────────────────────────────────────────────────────┬─────────┬─────────────┬────────────────┬────────────┬──────────┬──────────────────────────────────┐
# │ job_id                                             ┆ plan    ┆ render      ┆ status         ┆ entry_mode ┆ revision ┆ created_at                       │
# │ ---                                                ┆ ---     ┆ ---         ┆ ---            ┆ ---        ┆ ---      ┆ ---                              │
# │ str                                                ┆ str     ┆ str         ┆ str            ┆ str        ┆ i64      ┆ str                              │
# ╞════════════════════════════════════════════════════╪═════════╪═════════════╪════════════════╪════════════╪══════════╪══════════════════════════════════╡
# │ test_beauty_reservation_20260608075315             ┆ free    ┆ balanced    ┆ done           ┆ chat_start ┆ 1        ┆ 2026-06-08T07:57:04.669334+00:00 │
# │ test_flower_graduation_discount_20260608075315     ┆ free    ┆ balanced    ┆ done           ┆ chat_start ┆ 1        ┆ 2026-06-08T07:53:15.327432+00:00 │
# │ test_beauty_reservation_20260608073200             ┆ free    ┆ balanced    ┆ input_received ┆ chat_start ┆ 1        ┆ 2026-06-08T07:32:21.542604+00:00 │
# │ test_flower_graduation_discount_20260608073200     ┆ free    ┆ balanced    ┆ input_received ┆ chat_start ┆ 1        ┆ 2026-06-08T07:32:00.362933+00:00 │
# │ test_bespoke_bridal_atelier_nearest_20260608072551 ┆ free    ┆ balanced    ┆ input_received ┆ chat_start ┆ 1        ┆ 2026-06-08T07:25:52.155018+00:00 │
# │ test_restaurant_custom_copy_20260608072551         ┆ free    ┆ balanced    ┆ input_received ┆ chat_start ┆ 1        ┆ 2026-06-08T07:25:51.644150+00:00 │
# │ test_cafe_explicit_injection_20260608070815        ┆ free    ┆ fast        ┆ done           ┆ chat_start ┆ 1        ┆ 2026-06-08T07:08:15.166095+00:00 │
# │ test_premium_kitchen_showroom_20260608070256       ┆ free    ┆ fast        ┆ done           ┆ chat_start ┆ 1        ┆ 2026-06-08T07:02:56.917490+00:00 │
# │ test_adult_goods_store_20260608063943              ┆ free    ┆ fast        ┆ done           ┆ chat_start ┆ 1        ┆ 2026-06-08T06:39:43.442994+00:00 │
# │ test_cafe_morning_set_20260608011644               ┆ premium ┆ premium_api ┆ done           ┆ chat_start ┆ 1        ┆ 2026-06-08T01:16:44.839300+00:00 │
# │ test_cafe_iced_americano_20260608000015            ┆ free    ┆ balanced    ┆ done           ┆ chat_start ┆ 1        ┆ 2026-06-08T00:00:15.815007+00:00 │
# │ test_store_yearend_gift_20260607192552             ┆ free    ┆ balanced    ┆ done           ┆ chat_start ┆ 1        ┆ 2026-06-07T19:25:53.108605+00:00 │
# │ test_fitness_free_trial_20260607173418             ┆ premium ┆ balanced    ┆ done           ┆ chat_start ┆ 1        ┆ 2026-06-07T17:34:18.649829+00:00 │
# │ test_bespoke_florist_20260606202514                ┆ free    ┆ balanced    ┆ done           ┆ chat_start ┆ 1        ┆ 2026-06-06T20:25:14.800877+00:00 │
# └────────────────────────────────────────────────────┴─────────┴─────────────┴────────────────┴────────────┴──────────┴──────────────────────────────────┘

# %% [markdown]
# ### llm_calls — fallback summary per job (fb_total must be 0 for a valid run)

# %%
q(OPS_DB, '''
  SELECT job_id,
         COUNT(*)            AS llm_calls,
         SUM(fallback_used)  AS fb_total,
         SUM(success)        AS ok_total,
         GROUP_CONCAT(DISTINCT error_code) AS errors
  FROM llm_calls GROUP BY job_id ORDER BY job_id DESC LIMIT 30
''')
# Out:
# shape: (14, 5)
# ┌────────────────────────────────────────────────────┬───────────┬──────────┬──────────┬────────────────────────────────────────────────────────────────┐
# │ job_id                                             ┆ llm_calls ┆ fb_total ┆ ok_total ┆ errors                                                         │
# │ ---                                                ┆ ---       ┆ ---      ┆ ---      ┆ ---                                                            │
# │ str                                                ┆ i64       ┆ i64      ┆ i64      ┆ str                                                            │
# ╞════════════════════════════════════════════════════╪═══════════╪══════════╪══════════╪════════════════════════════════════════════════════════════════╡
# │ test_store_yearend_gift_20260607192552             ┆ 2         ┆ 2        ┆ 0        ┆ free_plan_deterministic_fallback                               │
# │ test_restaurant_custom_copy_20260608072551         ┆ 1         ┆ 1        ┆ 0        ┆ free_plan_deterministic_fallback                               │
# │ test_premium_kitchen_showroom_20260608070256       ┆ 2         ┆ 2        ┆ 0        ┆ llm_api_error:APITimeoutError,free_plan_deterministic_fallback │
# │ test_flower_graduation_discount_20260608075315     ┆ 2         ┆ 1        ┆ 1        ┆ free_plan_deterministic_fallback                               │
# │ test_flower_graduation_discount_20260608073200     ┆ 2         ┆ 1        ┆ 1        ┆ free_plan_deterministic_fallback                               │
# │ test_fitness_free_trial_20260607173418             ┆ 4         ┆ 0        ┆ 4        ┆ null                                                           │
# │ test_cafe_morning_set_20260608011644               ┆ 4         ┆ 0        ┆ 4        ┆ null                                                           │
# │ test_cafe_iced_americano_20260608000015            ┆ 2         ┆ 2        ┆ 0        ┆ free_plan_deterministic_fallback                               │
# │ test_cafe_explicit_injection_20260608070815        ┆ 2         ┆ 1        ┆ 1        ┆ free_plan_deterministic_fallback                               │
# │ test_bespoke_florist_20260606202514                ┆ 2         ┆ 2        ┆ 0        ┆ free_plan_deterministic_fallback                               │
# │ test_bespoke_bridal_atelier_nearest_20260608072551 ┆ 2         ┆ 1        ┆ 1        ┆ free_plan_deterministic_fallback                               │
# │ test_beauty_reservation_20260608075315             ┆ 2         ┆ 1        ┆ 1        ┆ free_plan_deterministic_fallback                               │
# │ test_beauty_reservation_20260608073200             ┆ 2         ┆ 1        ┆ 1        ┆ free_plan_deterministic_fallback                               │
# │ test_adult_goods_store_20260608063943              ┆ 2         ┆ 2        ┆ 0        ┆ llm_api_error:ValidationError,free_plan_deterministic_fallback │
# └────────────────────────────────────────────────────┴───────────┴──────────┴──────────┴────────────────────────────────────────────────────────────────┘

# %% [markdown]
# ### llm_calls — per-node detail (model / fallback / error / cost)

# %%
q(OPS_DB, '''
  SELECT job_id, node_name, model_class, model_name,
         success AS ok, fallback_used AS fb,
         COALESCE(error_code,'') AS error_code,
         total_tokens AS tok, cost_usd, cost_source
  FROM llm_calls ORDER BY id DESC LIMIT 60
''')
# Out:
# shape: (31, 10)
# ┌────────────────────────────────────────────────────┬───────────────────────────┬───────────────┬────────────────┬─────┬─────┬──────────────────────────────────┬──────┬──────────┬─────────────┐
# │ job_id                                             ┆ node_name                 ┆ model_class   ┆ model_name     ┆ ok  ┆ fb  ┆ error_code                       ┆ tok  ┆ cost_usd ┆ cost_source │
# │ ---                                                ┆ ---                       ┆ ---           ┆ ---            ┆ --- ┆ --- ┆ ---                              ┆ ---  ┆ ---      ┆ ---         │
# │ str                                                ┆ str                       ┆ str           ┆ str            ┆ i64 ┆ i64 ┆ str                              ┆ i64  ┆ f64      ┆ str         │
# ╞════════════════════════════════════════════════════╪═══════════════════════════╪═══════════════╪════════════════╪═════╪═════╪══════════════════════════════════╪══════╪══════════╪═════════════╡
# │ test_beauty_reservation_20260608075315             ┆ copy_candidate_generation ┆ local_quality ┆ gemma4-e4b-gpu ┆ 1   ┆ 0   ┆                                  ┆ null ┆ 0.0      ┆ self_hosted │
# │ test_beauty_reservation_20260608075315             ┆ tone_binding              ┆ mock          ┆ mock           ┆ 0   ┆ 1   ┆ free_plan_deterministic_fallback ┆ null ┆ 0.0      ┆ adapter     │
# │ test_flower_graduation_discount_20260608075315     ┆ copy_candidate_generation ┆ local_quality ┆ gemma4-e4b-gpu ┆ 1   ┆ 0   ┆                                  ┆ null ┆ 0.0      ┆ self_hosted │
# │ test_flower_graduation_discount_20260608075315     ┆ tone_binding              ┆ mock          ┆ mock           ┆ 0   ┆ 1   ┆ free_plan_deterministic_fallback ┆ null ┆ 0.0      ┆ adapter     │
# │ test_beauty_reservation_20260608073200             ┆ copy_candidate_generation ┆ local_quality ┆ gemma4-e4b-gpu ┆ 1   ┆ 0   ┆                                  ┆ null ┆ 0.0      ┆ self_hosted │
# │ test_beauty_reservation_20260608073200             ┆ tone_binding              ┆ mock          ┆ mock           ┆ 0   ┆ 1   ┆ free_plan_deterministic_fallback ┆ null ┆ 0.0      ┆ adapter     │
# │ test_flower_graduation_discount_20260608073200     ┆ copy_candidate_generation ┆ local_quality ┆ gemma4-e4b-gpu ┆ 1   ┆ 0   ┆                                  ┆ null ┆ 0.0      ┆ self_hosted │
# │ test_flower_graduation_discount_20260608073200     ┆ tone_binding              ┆ mock          ┆ mock           ┆ 0   ┆ 1   ┆ free_plan_deterministic_fallback ┆ null ┆ 0.0      ┆ adapter     │
# │ test_bespoke_bridal_atelier_nearest_20260608072551 ┆ copy_candidate_generation ┆ local_quality ┆ gemma4-e4b-gpu ┆ 1   ┆ 0   ┆                                  ┆ null ┆ 0.0      ┆ self_hosted │
# │ test_bespoke_bridal_atelier_nearest_20260608072551 ┆ tone_binding              ┆ mock          ┆ mock           ┆ 0   ┆ 1   ┆ free_plan_deterministic_fallback ┆ null ┆ 0.0      ┆ adapter     │
# │ test_restaurant_custom_copy_20260608072551         ┆ tone_binding              ┆ mock          ┆ mock           ┆ 0   ┆ 1   ┆ free_plan_deterministic_fallback ┆ null ┆ 0.0      ┆ adapter     │
# │ test_cafe_explicit_injection_20260608070815        ┆ copy_candidate_generation ┆ local_quality ┆ gemma4-e4b-gpu ┆ 1   ┆ 0   ┆                                  ┆ null ┆ 0.0      ┆ self_hosted │
# │ test_cafe_explicit_injection_20260608070815        ┆ tone_binding              ┆ mock          ┆ mock           ┆ 0   ┆ 1   ┆ free_plan_deterministic_fallback ┆ null ┆ 0.0      ┆ adapter     │
# │ test_premium_kitchen_showroom_20260608070256       ┆ copy_candidate_generation ┆ local_quality ┆ gemma4-e4b-gpu ┆ 0   ┆ 1   ┆ llm_api_error:APITimeoutError    ┆ null ┆ 0.0      ┆ self_hosted │
# │ test_premium_kitchen_showroom_20260608070256       ┆ tone_binding              ┆ mock          ┆ mock           ┆ 0   ┆ 1   ┆ free_plan_deterministic_fallback ┆ null ┆ 0.0      ┆ adapter     │
# │ test_adult_goods_store_20260608063943              ┆ copy_candidate_generation ┆ local_quality ┆ gemma4-e4b-gpu ┆ 0   ┆ 1   ┆ llm_api_error:ValidationError    ┆ null ┆ 0.0      ┆ self_hosted │
# │ test_adult_goods_store_20260608063943              ┆ tone_binding              ┆ mock          ┆ mock           ┆ 0   ┆ 1   ┆ free_plan_deterministic_fallback ┆ null ┆ 0.0      ┆ adapter     │
# │ test_cafe_morning_set_20260608011644               ┆ prompt_critic             ┆ api_full      ┆ api_full       ┆ 1   ┆ 0   ┆                                  ┆ 2468 ┆ 0.02557  ┆ exact       │
# │ test_cafe_morning_set_20260608011644               ┆ copy_candidate_generation ┆ api_mini      ┆ api_mini       ┆ 1   ┆ 0   ┆                                  ┆ 3434 ┆ 0.005339 ┆ exact       │
# │ test_cafe_morning_set_20260608011644               ┆ tone_binding              ┆ api_mini      ┆ api_mini       ┆ 1   ┆ 0   ┆                                  ┆ 1293 ┆ 0.002845 ┆ exact       │
# │ test_cafe_morning_set_20260608011644               ┆ validator                 ┆ api_mini      ┆ api_mini       ┆ 1   ┆ 0   ┆                                  ┆ 620  ┆ 0.000911 ┆ exact       │
# │ test_cafe_iced_americano_20260608000015            ┆ copy_candidate_generation ┆ local_quality ┆ local_quality  ┆ 0   ┆ 1   ┆ free_plan_deterministic_fallback ┆ null ┆ 0.0      ┆ self_hosted │
# │ test_cafe_iced_americano_20260608000015            ┆ tone_binding              ┆ mock          ┆ mock           ┆ 0   ┆ 1   ┆ free_plan_deterministic_fallback ┆ null ┆ 0.0      ┆ adapter     │
# │ test_store_yearend_gift_20260607192552             ┆ copy_candidate_generation ┆ local_quality ┆ local_quality  ┆ 0   ┆ 1   ┆ free_plan_deterministic_fallback ┆ null ┆ 0.0      ┆ self_hosted │
# │ test_store_yearend_gift_20260607192552             ┆ tone_binding              ┆ mock          ┆ mock           ┆ 0   ┆ 1   ┆ free_plan_deterministic_fallback ┆ null ┆ 0.0      ┆ adapter     │
# │ test_fitness_free_trial_20260607173418             ┆ prompt_critic             ┆ api_full      ┆ api_full       ┆ 1   ┆ 0   ┆                                  ┆ 2100 ┆ 0.021    ┆ exact       │
# │ test_fitness_free_trial_20260607173418             ┆ copy_candidate_generation ┆ api_mini      ┆ api_mini       ┆ 1   ┆ 0   ┆                                  ┆ 3378 ┆ 0.004626 ┆ exact       │
# │ test_fitness_free_trial_20260607173418             ┆ tone_binding              ┆ api_mini      ┆ api_mini       ┆ 1   ┆ 0   ┆                                  ┆ 1332 ┆ 0.003069 ┆ exact       │
# │ test_fitness_free_trial_20260607173418             ┆ validator                 ┆ api_mini      ┆ api_mini       ┆ 1   ┆ 0   ┆                                  ┆ 602  ┆ 0.000883 ┆ exact       │
# │ test_bespoke_florist_20260606202514                ┆ copy_candidate_generation ┆ local_quality ┆ local_quality  ┆ 0   ┆ 1   ┆ free_plan_deterministic_fallback ┆ null ┆ 0.0      ┆ self_hosted │
# │ test_bespoke_florist_20260606202514                ┆ tone_binding              ┆ mock          ┆ mock           ┆ 0   ┆ 1   ┆ free_plan_deterministic_fallback ┆ null ┆ 0.0      ┆ adapter     │
# └────────────────────────────────────────────────────┴───────────────────────────┴───────────────┴────────────────┴─────┴─────┴──────────────────────────────────┴──────┴──────────┴─────────────┘

# %% [markdown]
# ### node_executions — status & latency (t2i_generation dominates wall time)

# %%
# set a job_id to focus, or leave '' for the latest job
JOB_ID = ''
if not JOB_ID:
    JOB_ID = q(OPS_DB, 'SELECT job_id FROM jobs ORDER BY created_at DESC LIMIT 1')[0, 0]
print('JOB_ID =', JOB_ID)
q(OPS_DB, '''
  SELECT node_name, status, latency_ms AS ms,
         SUBSTR(COALESCE(error_message,''),1,50) AS err
  FROM node_executions WHERE job_id=? ORDER BY id
''', (JOB_ID,))
# Out:
# JOB_ID = test_beauty_reservation_20260608075315
# shape: (25, 4)
# ┌────────────────────────────────────┬───────────┬────────┬─────┐
# │ node_name                          ┆ status    ┆ ms     ┆ err │
# │ ---                                ┆ ---       ┆ ---    ┆ --- │
# │ str                                ┆ str       ┆ i64    ┆ str │
# ╞════════════════════════════════════╪═══════════╪════════╪═════╡
# │ input                              ┆ completed ┆ 8      ┆     │
# │ validator                          ┆ completed ┆ 4      ┆     │
# │ options                            ┆ started   ┆ null   ┆     │
# │ options                            ┆ completed ┆ 3      ┆     │
# │ state_update                       ┆ completed ┆ 4      ┆     │
# │ validator                          ┆ completed ┆ 3      ┆     │
# │ format_planner                     ┆ completed ┆ 4      ┆     │
# │ tone_binding                       ┆ completed ┆ 11     ┆     │
# │ copy_candidate_generation          ┆ completed ┆ 100675 ┆     │
# │ copy_candidate_selection_interrupt ┆ started   ┆ null   ┆     │
# │ copy_candidate_selection_interrupt ┆ completed ┆ 9      ┆     │
# │ state_update_selected_copy         ┆ completed ┆ 15     ┆     │
# │ copy_spec_parser                   ┆ completed ┆ 20     ┆     │
# │ text_style_binder                  ┆ completed ┆ 10     ┆     │
# │ text_layout_planner                ┆ completed ┆ 11     ┆     │
# │ image_prompt_planner               ┆ completed ┆ 27     ┆     │
# │ prompt_renderer                    ┆ completed ┆ 20     ┆     │
# │ t2i_request_builder                ┆ completed ┆ 11     ┆     │
# │ t2i_generation                     ┆ completed ┆ 104806 ┆     │
# │ background_validation              ┆ completed ┆ 18     ┆     │
# │ safe_area_gate                     ┆ completed ┆ 5      ┆     │
# │ text_renderer                      ┆ completed ┆ 272    ┆     │
# │ readability_gate                   ┆ completed ┆ 43     ┆     │
# │ final_validation                   ┆ completed ┆ 13     ┆     │
# │ result                             ┆ completed ┆ 5      ┆     │
# └────────────────────────────────────┴───────────┴────────┴─────┘

# %% [markdown]
# ### node_state_outputs — 각 노드가 state에 쓴 내용 (per node)
# 위 `node_executions`는 status/latency만 보여줌. 이 셀은 각 노드가 실제로 **쓴 필드 수 + 출력 스냅샷**을 함께 표시. 전체 출력은 `show_node('<node_name>')`.

# %%
# 각 노드 statement: status + latency + 쓴 필드 수 + snapshot head (JOB_ID 재사용)
state = q(OPS_DB, '''
  SELECT e.node_name, e.status, e.latency_ms AS ms,
         json_array_length(s.fields_written) AS n_fields,
         SUBSTR(s.output_snapshot, 1, 140) AS snapshot_head
  FROM node_executions e
  LEFT JOIN node_state_outputs s ON s.node_exec_id = e.id
  WHERE e.job_id=? ORDER BY e.id
''', (JOB_ID,))
state
# Out:
# shape: (25, 5)
# ┌────────────────────────────────────┬───────────┬────────┬──────────┬─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┐
# │ node_name                          ┆ status    ┆ ms     ┆ n_fields ┆ snapshot_head                                                                                                                                           │
# │ ---                                ┆ ---       ┆ ---    ┆ ---      ┆ ---                                                                                                                                                     │
# │ str                                ┆ str       ┆ i64    ┆ i64      ┆ str                                                                                                                                                     │
# ╞════════════════════════════════════╪═══════════╪════════╪══════════╪═════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════╡
# │ input                              ┆ completed ┆ 8      ┆ 92       ┆ {"schema_version": "llm_marketing_v1", "job_id": "test_beauty_reservation_20260608075315", "thread_id": "test_beauty_reservation_20260608075            │
# │ validator                          ┆ completed ┆ 4      ┆ 14       ┆ {"context": {"business_type": "beauty_salon", "item_or_service": null, "region_type": null, "target_persona": null, "promotion_goal": "reser            │
# │ options                            ┆ started   ┆ null   ┆ null     ┆ null                                                                                                                                                    │
# │ options                            ┆ completed ┆ 3      ┆ 3        ┆ {"user_selection": {"job_id": "test_beauty_reservation_20260608075315", "thread_id": "test_beauty_reservation_20260608075315_thread", "field            │
# │ state_update                       ┆ completed ┆ 4      ┆ 6        ┆ {"context": {"business_type": "beauty_salon", "item_or_service": "예약 서비스", "region_type": null, "target_persona": null, "promotion_goal": "r       │
# │ validator                          ┆ completed ┆ 3      ┆ 14       ┆ {"context": {"business_type": "beauty_salon", "item_or_service": "예약 서비스", "region_type": null, "target_persona": null, "promotion_goal": "r       │
# │ format_planner                     ┆ completed ┆ 4      ┆ 6        ┆ {"ad_format_spec": {"ad_format": "instagram_feed", "platform": "instagram", "aspect_ratio": "1:1", "width": 1080, "height": 1080, "informati            │
# │ tone_binding                       ┆ completed ┆ 11     ┆ 5        ┆ {"tone_binding_output": {"tone_profile": "polished_confident", "copy_constraints": ["no_hallucinated_contact", "no_unprovided_discount", "no            │
# │ copy_candidate_generation          ┆ completed ┆ 100675 ┆ 8        ┆ {"copy_candidates": [{"id": "candidate_1", "headline": "나를 위한 휴식, 지금 예", "subcopy": null, "cta": "예약하고 아름다워지기", "hashtags": [],      │
# │                                    ┆           ┆        ┆          ┆ "tone_label"                                                                                                                                            │
# │ copy_candidate_selection_interrupt ┆ started   ┆ null   ┆ null     ┆ null                                                                                                                                                    │
# │ copy_candidate_selection_interrupt ┆ completed ┆ 9      ┆ 2        ┆ {"copy_selection": {"selected_copy_id": "candidate_1", "selected_channel_id": "instagram-feed", "selected_ad_format": "instagram_feed", "sel            │
# │ state_update_selected_copy         ┆ completed ┆ 15     ┆ 12       ┆ {"marketing_copy": {"headline": "나를 위한 휴식, 지금 예", "subcopy": null, "cta": "예약하고 아름다워지기", "price_line": null, "period_line": null,    │
# │                                    ┆           ┆        ┆          ┆ "hashtags"                                                                                                                                              │
# │ copy_spec_parser                   ┆ completed ┆ 20     ┆ 3        ┆ {"copy_spec": {"schema_version": "1.0", "spec_id": "copy_spec_967a96081e3e4baaa123d8157318ddb0", "items": [{"role": "headline", "text": "나를           │
# │ text_style_binder                  ┆ completed ┆ 10     ┆ 3        ┆ {"text_style_spec": {"schema_version": "1.0", "profile": "emotional", "typography": {"headline_font": "MaruBuri", "body_font": "MaruBuri", "            │
# │ text_layout_planner                ┆ completed ┆ 11     ┆ 3        ┆ {"text_layout_spec": {"schema_version": "1.0", "spec_id": "text_layout_f4cb761c0e6647a0814810ad9f02a6ba", "template": "dynamic_side_split",             │
# │ image_prompt_planner               ┆ completed ┆ 27     ┆ 6        ┆ {"image_prompt_spec": {"schema_version": "1.0", "scene_description": "clean commercial advertising background for 예약 서비스; soft pastel beauty       │
# │ prompt_renderer                    ┆ completed ┆ 20     ┆ 3        ┆ {"engine": "sd35_large", "prompt_render_output": {"engine": "sd35_large", "positive_prompt": "Create a text-free advertising background for             │
# │ t2i_request_builder                ┆ completed ┆ 11     ┆ 2        ┆ {"t2i_request": {"input_image_paths": [], "negative_prompt": "text, letters, words, Korean text, logo, watermark, menu board, label, price t            │
# │ t2i_generation                     ┆ completed ┆ 104806 ┆ 6        ┆ {"t2i_result": {"engine": "sd35_large", "image_paths": ["data/outputs/test_beauty_reservation_20260608075315/sd35_large_0.png"], "seed": nul            │
# │ background_validation              ┆ completed ┆ 18     ┆ 3        ┆ {"background_validation_report": {"schema_version": "1.0", "overall_pass": true, "image_exists": true, "image_path": "data/outputs/test_beau            │
# │ safe_area_gate                     ┆ completed ┆ 5      ┆ 2        ┆ {"safe_area_report": {"schema_version": "1.0", "overall_pass": true, "reserved_text_area_count": 2, "product_overlap_warnings": [], "bbox_is            │
# │ text_renderer                      ┆ completed ┆ 272    ┆ 5        ┆ {"final_image_path": "data/outputs/test_beauty_reservation_20260608075315/final_composite.png", "render_result": {"schema_version": "1.0", "            │
# │ readability_gate                   ┆ completed ┆ 43     ┆ 2        ┆ {"readability_report": {"schema_version": "1.0", "overall_pass": false, "slots": [{"slot_id": "slot_headline", "role": "headline", "backgrou            │
# │ final_validation                   ┆ completed ┆ 13     ┆ 2        ┆ {"final_validation_report": {"schema_version": "1.0", "overall_pass": false, "background_pass": true, "safe_area_pass": true, "readability_p            │
# │ result                             ┆ completed ┆ 5      ┆ 4        ┆ {"result_payload": {"schema_version": "1.0", "job_id": "test_beauty_reservation_20260608075315", "thread_id": "test_beauty_reservation_20260            │
# └────────────────────────────────────┴───────────┴────────┴──────────┴─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┘

# %% [markdown]
# #### show_node() 에 넣을 수 있는 노드 이름 목록
# marketing 그래프 28노드 (실행된 노드만 DB에 있음). HITL 분기라 job마다 일부만 존재:
#
# | 단계 | 노드 이름 |
# |---|---|
# | 입력/전처리 | `input` · `reference_template_resolve` · `product_preprocess` · `reference_preprocess` |
# | 컨텍스트 | `validator` · `options` · `state_update` |
# | 포맷/톤 | `format_planner` · `tone_binding` |
# | 카피 | `copy_candidate_generation` · `copy_candidate_selection_interrupt` · `state_update_selected_copy` · `auto_pilot_copywriting` · `custom_copy_input` · `custom_copy_validation` · `no_copy_bypass` |
# | 레이아웃 | `copy_spec_parser` · `text_style_binder` · `text_layout_planner` |
# | 이미지 프롬프트/T2I | `image_prompt_planner` · `prompt_renderer` · `t2i_request_builder` · `t2i_generation` |
# | 배경 검증/수정 | `background_ocr_gate` · `ocr_image_revision` · `background_validation` · `safe_area_gate` |
# | 텍스트 렌더/최종 | `text_renderer` · `final_ocr_gate` · `ocr_layout_revision` · `readability_gate` · `final_validation` · `result` |
#
# > 이 job에 실제 존재하는 노드만 보려면:
# > `q(OPS_DB, "SELECT DISTINCT node_name FROM node_executions WHERE job_id=? ORDER BY id", (JOB_ID,))`

# %%
# 특정 노드 전체 출력 보기 (fields_written + 예쁨 snapshot JSON)
def show_node(node_name, job_id=None):
    jid = job_id or JOB_ID
    with sqlite3.connect(OPS_DB) as c:
        row = c.execute('''
            SELECT s.fields_written, s.output_snapshot
            FROM node_state_outputs s JOIN node_executions e ON s.node_exec_id=e.id
            WHERE e.job_id=? AND s.node_name=? ORDER BY s.id DESC LIMIT 1
        ''', (jid, node_name)).fetchone()
    if not row:
        print(f'no state output for node={node_name!r} job={jid!r}'); return
    fields, snap = row
    import json as _json
    print('fields_written:', ', '.join(_json.loads(fields)))
    print('-' * 60)
    try:
        print(_json.dumps(_json.loads(snap), indent=2, ensure_ascii=False))
    except Exception:
        print(snap)

show_node('image_prompt_planner')

# %% [markdown]
# ### 프롬프트만 보기 (prompts only)
# `show_prompts('<job_id>')` — 그 job이 생성한 **이미지/T2I 프롬프트**만 추출: `image_prompt`(planner), `t2i_request.prompt`(렌더 입력), `prompt_render_output`.
# > 주의: LLM 호출의 **raw system/user 프롬프트는 DB에 없음** — `sanitize_metadata()`가 `prompt`/`api_key` 키를 LLMCallResult.metadata에서 제거(불변식). 여기 보이는 건 파이프라인이 만든 *이미지 생성용 프롬프트 텍스트*만.

# %%
# 프롬프트 필드만 추출 (이미지 생성 프롬프트 — raw LLM 프롬프트 아님)
def show_prompts(job_id=None):
    import json as _json
    jid = job_id or JOB_ID
    def _snap(node):
        with sqlite3.connect(OPS_DB) as c:
            r = c.execute('''SELECT s.output_snapshot FROM node_state_outputs s
                JOIN node_executions e ON s.node_exec_id=e.id
                WHERE e.job_id=? AND s.node_name=? ORDER BY s.id DESC LIMIT 1''', (jid, node)).fetchone()
        return _json.loads(r[0]) if r and r[0] else {}
    print('JOB_ID =', jid)
    # 1) 최종 T2I 프롬프트 (엔진에 실제 들어간 문자열) — prompt_render_output
    pr = _snap('prompt_renderer').get('prompt_render_output') or {}
    if pr.get('positive_prompt'):
        print('\n[final positive_prompt → %s]' % pr.get('engine','?')); print(pr['positive_prompt'])
    if pr.get('negative_prompt'):
        print('\n[negative_prompt]'); print(pr['negative_prompt'])
    # 2) 구조화 ImagePrompt (planner) — 필드별
    ip = _snap('image_prompt_planner').get('image_prompt') or {}
    if ip:
        print('\n[image_prompt (structured)]')
        for k in ('subject','scene','style','lighting','composition','copy_space','color_palette','avoid_text'):
            if ip.get(k): print(f'  {k}: {ip[k]}')
        if ip.get('negative_prompt'): print(f'  negative_prompt: {ip["negative_prompt"]}')
    # 3) t2i_request negative (planner→request 전달분)
    req = _snap('t2i_request_builder').get('t2i_request') or {}
    if req.get('negative_prompt') and req['negative_prompt'] != pr.get('negative_prompt'):
        print('\n[t2i_request.negative_prompt]'); print(req['negative_prompt'])

show_prompts()
# Out:
# JOB_ID = test_cafe_morning_set_20260608011644
#
# [final positive_prompt → gpt_image_2]
# Create a text-free advertising background for later Korean copy overlay. Create a text-free advertising background for later Korean copy overlay. Reserve clean negative space for Korean text overlay in post-processing. Keep reserved text areas uncluttered, smooth, low-detail, and visually calm. Do not include any text, letters, words, numbers, logos, signage, labels, watermark, or typography. Create a premium realistic advertising background for cafe. The main subject is 모닝 커피 세트, presented as a premium cafe drink or dessert product hero on the right side. Place the main subject on the right and keep a clean, uncluttered left negative space. Use pastel pink, cream, soft premium, warm, emotional. Secondary props: fresh ingredients, delicate pastel saucer, soft napkin. This image is intended for later Korean copy overlay. Additional visual/reference guidance: Reflect this user-selected mood/tone: 감성적인. no readable text. no Korean letters. no logos. no signage. no watermark. no typography. no menu text. no price tags. clean reserved negative space for later copy overlay. Do not create text, labels, logos, or watermarks.
#
# [negative_prompt]
# text, letters, typography, words, captions, subtitles, alphabets, numbers, korean characters, hangul, watermark, logo, signature, cluttered background in reserved areas, busy pattern in negative space, busy cafe signage, printed menu text, text, watermark, logo, signature, letters, numbers, broken typography, deformed object, low quality, blurry, artifacts, distorted food, plastic texture, oversaturated, uncanny, extra fingers, unwanted people, people where not requested
#
# [image_prompt (structured)]
#   subject: 모닝 커피 세트
#   scene: clean commercial advertising background for 모닝 커피 세트; soft cream cafe dessert background
#   style: clean commercial advertising background
#   lighting: warm natural daylight
#   composition: fresh fruit or drink product hero with minimal props. Reserve a medium clean empty area in the lower center region and a small clean empty area in the lower center region and a small clean empty area in the lower center region as uncluttered negative space for Korean text overlay in post-processing. Keep those regions calm, simple, and free of visual clutter. Main subject zone: center lower third.
#   copy_space: bottom
#   avoid_text: True
#   negative_prompt: text, letters, typography, words, captions, subtitles, alphabets, numbers, korean characters, hangul, watermark, logo, signature, cluttered background in reserved areas, busy pattern in negative space, busy cafe signage, printed menu text, text, watermark, logo, signature, letters, numbers, broken typography, deformed object, low quality, blurry, artifacts, distorted food, plastic texture, oversaturated, uncanny, extra fingers, unwanted people, people where not requested

# %% [markdown]
# ### job_cost_summary — tokens, USD, T2I engine & image cost

# %%
q(OPS_DB, '''
  SELECT job_id, total_api_calls AS api, fallback_calls AS fb,
         total_tokens AS tok, total_cost_usd AS usd,
         t2i_engine, t2i_image_count AS imgs, t2i_cost_usd, t2i_cost_source,
         cost_estimated AS est
  FROM job_cost_summary ORDER BY rowid DESC LIMIT 30
''')
# Out:
# shape: (5, 10)
# ┌─────────────┬─────┬─────┬──────┬──────────┬─────────────┬──────┬─────────────┬─────────────┬─────┐
# │ job_id      ┆ api ┆ fb  ┆ tok  ┆ usd      ┆ t2i_engine  ┆ imgs ┆ t2i_cost_us ┆ t2i_cost_so ┆ est │
# │ ---         ┆ --- ┆ --- ┆ ---  ┆ ---      ┆ ---         ┆ ---  ┆ d           ┆ urce        ┆ --- │
# │ str         ┆ i64 ┆ i64 ┆ i64  ┆ f64      ┆ str         ┆ i64  ┆ ---         ┆ ---         ┆ i64 │
# │             ┆     ┆     ┆      ┆          ┆             ┆      ┆ f64         ┆ str         ┆     │
# ╞═════════════╪═════╪═════╪══════╪══════════╪═════════════╪══════╪═════════════╪═════════════╪═════╡
# │ test_cafe_m ┆ 4   ┆ 0   ┆ 7815 ┆ 0.074665 ┆ gpt_image_2 ┆ 1    ┆ 0.04        ┆ exact       ┆ 0   │
# │ orning_set_ ┆     ┆     ┆      ┆          ┆             ┆      ┆             ┆             ┆     │
# │ 20260608011 ┆     ┆     ┆      ┆          ┆             ┆      ┆             ┆             ┆     │
# │ 644         ┆     ┆     ┆      ┆          ┆             ┆      ┆             ┆             ┆     │
# │ test_cafe_i ┆ 0   ┆ 2   ┆ 0    ┆ 0.019133 ┆ sd35_large  ┆ 1    ┆ 0.019133    ┆ gpu_exact   ┆ 0   │
# │ ced_america ┆     ┆     ┆      ┆          ┆             ┆      ┆             ┆             ┆     │
# │ no_20260608 ┆     ┆     ┆      ┆          ┆             ┆      ┆             ┆             ┆     │
# │ 000015      ┆     ┆     ┆      ┆          ┆             ┆      ┆             ┆             ┆     │
# │ test_store_ ┆ 0   ┆ 2   ┆ 0    ┆ 0.0      ┆ sd35_large  ┆ 1    ┆ null        ┆ gpu_unprice ┆ 1   │
# │ yearend_gif ┆     ┆     ┆      ┆          ┆             ┆      ┆             ┆ d           ┆     │
# │ t_202606071 ┆     ┆     ┆      ┆          ┆             ┆      ┆             ┆             ┆     │
# │ 92552       ┆     ┆     ┆      ┆          ┆             ┆      ┆             ┆             ┆     │
# │ test_fitnes ┆ 4   ┆ 0   ┆ 7412 ┆ 0.029578 ┆ sd35_large  ┆ 1    ┆ null        ┆ gpu_unprice ┆ 1   │
# │ s_free_tria ┆     ┆     ┆      ┆          ┆             ┆      ┆             ┆ d           ┆     │
# │ l_202606071 ┆     ┆     ┆      ┆          ┆             ┆      ┆             ┆             ┆     │
# │ 73418       ┆     ┆     ┆      ┆          ┆             ┆      ┆             ┆             ┆     │
# │ test_bespok ┆ 0   ┆ 2   ┆ 0    ┆ 0.0      ┆ sd35_large  ┆ 1    ┆ null        ┆ gpu_unprice ┆ 1   │
# │ e_florist_2 ┆     ┆     ┆      ┆          ┆             ┆      ┆             ┆ d           ┆     │
# │ 02606062025 ┆     ┆     ┆      ┆          ┆             ┆      ┆             ┆             ┆     │
# │ 14          ┆     ┆     ┆      ┆          ┆             ┆      ┆             ┆             ┆     │
# └─────────────┴─────┴─────┴──────┴──────────┴─────────────┴──────┴─────────────┴─────────────┴─────┘

# %% [markdown]
# ### images — generated file paths (result node)

# %%
q(OPS_DB, '''
  SELECT ne.job_id,
         json_extract(nso.output_snapshot,'$.result_payload.output_path')           AS final_ad,
         json_extract(nso.output_snapshot,'$.result_payload.background_image_path')  AS background
  FROM node_state_outputs nso
  JOIN node_executions ne ON ne.id = nso.node_exec_id
  WHERE ne.node_name='result'
  GROUP BY ne.job_id ORDER BY ne.id DESC LIMIT 30
''')
# Out:
# shape: (5, 3)
# ┌────────────────────────────────┬────────────────────────────────┬────────────────────────────────┐
# │ job_id                         ┆ final_ad                       ┆ background                     │
# │ ---                            ┆ ---                            ┆ ---                            │
# │ str                            ┆ str                            ┆ str                            │
# ╞════════════════════════════════╪════════════════════════════════╪════════════════════════════════╡
# │ test_store_grand_open_20260608 ┆ /app/records/images/test_store ┆ /app/records/images/test_store │
# │ 004905                         ┆ _grand_open_20260608004905/fin ┆ _grand_open_20260608004905/sd3 │
# │                                ┆ al_composite.png               ┆ 5_large_0.png                  │
# │ test_cafe_iced_americano_20260 ┆ /app/records/images/test_cafe_ ┆ /app/records/images/test_cafe_ │
# │ 608000015                      ┆ iced_americano_20260608000015/ ┆ iced_americano_20260608000015/ │
# │                                ┆ final_composite.png            ┆ sd35_large_0.png               │
# │ test_store_yearend_gift_202606 ┆ /app/records/images/test_store ┆ /app/records/images/test_store │
# │ 07192552                       ┆ _yearend_gift_20260607192552/f ┆ _yearend_gift_20260607192552/s │
# │                                ┆ inal_composite.png             ┆ d35_large_0.png                │
# │ test_fitness_free_trial_202606 ┆ /app/records/images/test_fitne ┆ /app/records/images/test_fitne │
# │ 07173418                       ┆ ss_free_trial_20260607173418/f ┆ ss_free_trial_20260607173418/s │
# │                                ┆ inal_composite.png             ┆ d35_large_0.png                │
# │ test_bespoke_florist_202606062 ┆ /app/records/images/test_bespo ┆ /app/records/images/test_bespo │
# │ 02514                          ┆ ke_florist_20260606202514/fina ┆ ke_florist_20260606202514/sd35 │
# │                                ┆ l_composite.png                ┆ _large_0.png                   │
# └────────────────────────────────┴────────────────────────────────┴────────────────────────────────┘

# %% [markdown]
# ### schema_validations — failures only (empty = all passed)

# %%
q(OPS_DB, '''
  SELECT job_id, node_name, schema_name, field_name,
         SUBSTR(COALESCE(error_detail,''),1,80) AS err
  FROM schema_validations WHERE passed=0 ORDER BY id DESC LIMIT 50
''')
# Out:
# shape: (0, 5)
# ┌────────┬───────────┬─────────────┬────────────┬──────┐
# │ job_id ┆ node_name ┆ schema_name ┆ field_name ┆ err  │
# │ ---    ┆ ---       ┆ ---         ┆ ---        ┆ ---  │
# │ null   ┆ null      ┆ null        ┆ null       ┆ null │
# ╞════════╪═══════════╪═════════════╪════════════╪══════╡
# └────────┴───────────┴─────────────┴────────────┴──────┘

# %% [markdown]
# ### preview a generated image (optional)

# %%
from IPython.display import Image, display
row = q(OPS_DB, '''
  SELECT json_extract(nso.output_snapshot,'$.result_payload.output_path') AS final_ad
  FROM node_state_outputs nso JOIN node_executions ne ON ne.id=nso.node_exec_id
  WHERE ne.node_name='result' ORDER BY ne.id DESC LIMIT 1
''')
path = row[0, 0] if len(row) else None
print('path:', path)
if path and os.path.isfile(path):
    display(Image(filename=path))
else:
    print('file not reachable from here (may be a container path); open it directly.')
# Out:
# path: /app/records/images/test_cafe_morning_set_20260608011644/final_composite.png

# %% [markdown]
# # eval DB

# %% [markdown]
# ### eval_runs — overall score & verdict

# %%
q(EVAL_DB, '''
  SELECT job_id, eval_id, ROUND(overall_score,3) AS score, verdict,
         evaluator_id, evaluated_at
  FROM eval_runs ORDER BY evaluated_at DESC LIMIT 30
''')
# Out:
# shape: (5, 6)
# ┌───────────────────┬───────────────────┬───────┬────────────────┬──────────────┬──────────────────┐
# │ job_id            ┆ eval_id           ┆ score ┆ verdict        ┆ evaluator_id ┆ evaluated_at     │
# │ ---               ┆ ---               ┆ ---   ┆ ---            ┆ ---          ┆ ---              │
# │ str               ┆ str               ┆ f64   ┆ str            ┆ null         ┆ str              │
# ╞═══════════════════╪═══════════════════╪═══════╪════════════════╪══════════════╪══════════════════╡
# │ test_store_grand_ ┆ eval_83eddd44accc ┆ null  ┆ pending_scores ┆ null         ┆ 2026-06-08T00:51 │
# │ open_202606080049 ┆ 4d79ba8cfa989fcff ┆       ┆                ┆              ┆ :32.527499+00:00 │
# │ 05                ┆ 102               ┆       ┆                ┆              ┆                  │
# │ test_cafe_iced_am ┆ eval_2b15898d48e7 ┆ 3.412 ┆ major_revision ┆ null         ┆ 2026-06-08T00:01 │
# │ ericano_202606080 ┆ 4bddbc94c873829d4 ┆       ┆                ┆              ┆ :53.764151+00:00 │
# │ 00015             ┆ a3e               ┆       ┆                ┆              ┆                  │
# │ test_store_yearen ┆ eval_d0babc4546b2 ┆ 3.686 ┆ major_revision ┆ null         ┆ 2026-06-07T19:27 │
# │ d_gift_2026060719 ┆ 4504a03587bbfb212 ┆       ┆                ┆              ┆ :36.217588+00:00 │
# │ 2552              ┆ 329               ┆       ┆                ┆              ┆                  │
# │ test_fitness_free ┆ eval_7aa7e6531acb ┆ 3.502 ┆ major_revision ┆ null         ┆ 2026-06-07T17:36 │
# │ _trial_2026060717 ┆ 41c0b64d5dcd59e99 ┆       ┆                ┆              ┆ :34.492860+00:00 │
# │ 3418              ┆ fb0               ┆       ┆                ┆              ┆                  │
# │ test_bespoke_flor ┆ eval_d7ed198bb933 ┆ 3.248 ┆ major_revision ┆ null         ┆ 2026-06-06T20:26 │
# │ ist_2026060620251 ┆ 4aa7aeceed61c42b7 ┆       ┆                ┆              ┆ :52.107689+00:00 │
# │ 4                 ┆ ffc               ┆       ┆                ┆              ┆                  │
# └───────────────────┴───────────────────┴───────┴────────────────┴──────────────┴──────────────────┘

# %% [markdown]
# ### score_items — per-item scores by evaluator (llm / vlm / human)

# %%
q(EVAL_DB, '''
  SELECT er.job_id, si.evaluator_type, si.item_id, si.score,
         SUBSTR(COALESCE(si.notes,''),1,60) AS notes
  FROM score_items si JOIN eval_runs er ON er.eval_id = si.eval_id
  ORDER BY er.evaluated_at DESC, si.evaluator_type, si.item_id LIMIT 80
''')
# Out:
# shape: (64, 5)
# ┌───────────────────────────────┬────────────────┬─────────┬───────┬───────────────────────────────┐
# │ job_id                        ┆ evaluator_type ┆ item_id ┆ score ┆ notes                         │
# │ ---                           ┆ ---            ┆ ---     ┆ ---   ┆ ---                           │
# │ str                           ┆ str            ┆ str     ┆ i64   ┆ str                           │
# ╞═══════════════════════════════╪════════════════╪═════════╪═══════╪═══════════════════════════════╡
# │ test_cafe_iced_americano_2026 ┆ llm            ┆ II-1    ┆ 3     ┆ The context captures business │
# │ 0608000015                    ┆                ┆         ┆       ┆ type (cafe), item/service     │
# │                               ┆                ┆         ┆       ┆ (대표                         │
# │ test_cafe_iced_americano_2026 ┆ llm            ┆ II-2    ┆ 5     ┆ The validator reports no      │
# │ 0608000015                    ┆                ┆         ┆       ┆ missing_fields and retains    │
# │                               ┆                ┆         ┆       ┆ all rele                      │
# │ test_cafe_iced_americano_2026 ┆ llm            ┆ II-3    ┆ 5     ┆ The updated context is        │
# │ 0608000015                    ┆                ┆         ┆       ┆ internally consistent between │
# │                               ┆                ┆         ┆       ┆ state_u                       │
# │ test_cafe_iced_americano_2026 ┆ llm            ┆ III-3   ┆ 3     ┆ 감성적인 카페 분위기의        │
# │ 0608000015                    ┆                ┆         ┆       ┆ 헤드라인/서브카피와 CTA는     │
# │                               ┆                ┆         ┆       ┆ 톤에 부합하지만, 요청된 '여름 │
# │                               ┆                ┆         ┆       ┆ 시즌 아이스 아메리카노        │
# │ test_cafe_iced_americano_2026 ┆ llm            ┆ III-4   ┆ 4     ┆ CTA인 "메뉴 확인하기" is      │
# │ 0608000015                    ┆                ┆         ┆       ┆ clear and actionable but      │
# │                               ┆                ┆         ┆       ┆ lacks stronger sp             │
# │ test_cafe_iced_americano_2026 ┆ llm            ┆ III-5   ┆ 4     ┆ Copy is largely consistent    │
# │ 0608000015                    ┆                ┆         ┆       ┆ with the stated emotional     │
# │                               ┆                ┆         ┆       ┆ cafe br                       │
# │ test_cafe_iced_americano_2026 ┆ llm            ┆ IV-3    ┆ 4     ┆ The spec defines appropriate  │
# │ 0608000015                    ┆                ┆         ┆       ┆ distinct slots for headline,  │
# │                               ┆                ┆         ┆       ┆ su                            │
# │ test_cafe_iced_americano_2026 ┆ llm            ┆ IV-4    ┆ 3     ┆ The spec defines headline vs  │
# │ 0608000015                    ┆                ┆         ┆       ┆ body weights and size ratios  │
# │                               ┆                ┆         ┆       ┆ (h                            │
# │ test_cafe_iced_americano_2026 ┆ llm            ┆ IV-5    ┆ 3     ┆ Evidence shows a text layout  │
# │ 0608000015                    ┆                ┆         ┆       ┆ plan with a dynamic           │
# │                               ┆                ┆         ┆       ┆ side-split                    │
# │ test_cafe_iced_americano_2026 ┆ llm            ┆ V-3     ┆ 3     ┆ While the user plan is free,  │
# │ 0608000015                    ┆                ┆         ┆       ┆ the evidence shows 2 fallback │
# │                               ┆                ┆         ┆       ┆ c                             │
# │ test_cafe_iced_americano_2026 ┆ llm            ┆ V-4     ┆ 4     ┆ Evidence shows                │
# │ 0608000015                    ┆                ┆         ┆       ┆ failed_nodes=0, but does not  │
# │                               ┆                ┆         ┆       ┆ explicitly confi              │
# │ test_cafe_iced_americano_2026 ┆ vlm            ┆ III-6   ┆ 2     ┆ The image has a distorted,    │
# │ 0608000015                    ┆                ┆         ┆       ┆ glitchy storefront look with  │
# │                               ┆                ┆         ┆       ┆ mute                          │
# │ test_cafe_iced_americano_2026 ┆ vlm            ┆ IV-6    ┆ 1     ┆ The image contains clearly    │
# │ 0608000015                    ┆                ┆         ┆       ┆ visible generated text        │
# │                               ┆                ┆         ┆       ┆ artifacts,                    │
# │ test_cafe_iced_americano_2026 ┆ vlm            ┆ IV-7    ┆ 4     ┆ The image has a centered,     │
# │ 0608000015                    ┆                ┆         ┆       ┆ stable facade composition     │
# │                               ┆                ┆         ┆       ┆ with no                       │
# │ test_cafe_iced_americano_2026 ┆ vlm            ┆ IV-8    ┆ 4     ┆ The white overlaid text is    │
# │ 0608000015                    ┆                ┆         ┆       ┆ generally legible against the │
# │                               ┆                ┆         ┆       ┆ str                           │
# │ test_cafe_iced_americano_2026 ┆ vlm            ┆ IV-9    ┆ 2     ┆ The ad is not commercially    │
# │ 0608000015                    ┆                ┆         ┆       ┆ ready because the background  │
# │                               ┆                ┆         ┆       ┆ sign                          │
# │ test_store_yearend_gift_20260 ┆ llm            ┆ II-1    ┆ 3     ┆ The context captures some key │
# │ 607192552                     ┆                ┆         ┆       ┆ elements (store/business      │
# │                               ┆                ┆         ┆       ┆ type,                         │
# │ test_store_yearend_gift_20260 ┆ llm            ┆ II-2    ┆ 1     ┆ The validator reports         │
# │ 607192552                     ┆                ┆         ┆       ┆ missing_fields as empty and   │
# │                               ┆                ┆         ┆       ┆ sets remai                    │
# │ test_store_yearend_gift_20260 ┆ llm            ┆ II-3    ┆ 5     ┆ The updated validator context │
# │ 607192552                     ┆                ┆         ┆       ┆ matches the provided state    │
# │                               ┆                ┆         ┆       ┆ con                           │
# │ test_store_yearend_gift_20260 ┆ llm            ┆ III-3   ┆ 4     ┆ 감성적인 톤으로 보이는 간결한 │
# │ 607192552                     ┆                ┆         ┆       ┆ 헤드라인/CTA(“패키지/세트를   │
# │                               ┆                ┆         ┆       ┆ 지금 확인하세요”, “자세히     │
# │                               ┆                ┆         ┆       ┆ 보기”)를 사용했               │
# │ test_store_yearend_gift_20260 ┆ llm            ┆ III-4   ┆ 4     ┆ CTA가 '자세히 보기'로 존재해  │
# │ 607192552                     ┆                ┆         ┆       ┆ 행동 유도는 명확하나(구체적   │
# │                               ┆                ┆         ┆       ┆ 링크/다음 단계는 없음) 실행   │
# │                               ┆                ┆         ┆       ┆ 가능성은 다소                 │
# │ test_store_yearend_gift_20260 ┆ llm            ┆ III-5   ┆ 4     ┆ The Korean copy (“감성적인”   │
# │ 607192552                     ┆                ┆         ┆       ┆ tone set) is concise and      │
# │                               ┆                ┆         ┆       ┆ inviting (h                   │
# │ test_store_yearend_gift_20260 ┆ llm            ┆ IV-3    ┆ 4     ┆ The template defines a        │
# │ 607192552                     ┆                ┆         ┆       ┆ coherent set of three slots   │
# │                               ┆                ┆         ┆       ┆ (headline                     │
# │ test_store_yearend_gift_20260 ┆ llm            ┆ IV-4    ┆ 4     ┆ The provided typography spec  │
# │ 607192552                     ┆                ┆         ┆       ┆ assigns distinct headline     │
# │                               ┆                ┆         ┆       ┆ (weig                         │
# │ test_store_yearend_gift_20260 ┆ llm            ┆ IV-5    ┆ 2     ┆ Evidence shows a poster text  │
# │ 607192552                     ┆                ┆         ┆       ┆ template (top headline        │
# │                               ┆                ┆         ┆       ┆ center/p                      │
# │ test_store_yearend_gift_20260 ┆ llm            ┆ V-3     ┆ 4     ┆ The plan is free but there    │
# │ 607192552                     ┆                ┆         ┆       ┆ were 2 fallback calls with no │
# │                               ┆                ┆         ┆       ┆ suc                           │
# │ test_store_yearend_gift_20260 ┆ llm            ┆ V-4     ┆ 5     ┆ Evidence shows failed_nodes=0 │
# │ 607192552                     ┆                ┆         ┆       ┆ and no indication of failed   │
# │                               ┆                ┆         ┆       ┆ no                            │
# │ test_store_yearend_gift_20260 ┆ vlm            ┆ III-6   ┆ 3     ┆ The clean blue-and-white      │
# │ 607192552                     ┆                ┆         ┆       ┆ palette feels broadly         │
# │                               ┆                ┆         ┆       ┆ appropriate f                 │
# │ test_store_yearend_gift_20260 ┆ vlm            ┆ IV-6    ┆ 5     ┆ The image appears completely  │
# │ 607192552                     ┆                ┆         ┆       ┆ free of any visible letters,  │
# │                               ┆                ┆         ┆       ┆ nu                            │
# │ test_store_yearend_gift_20260 ┆ vlm            ┆ IV-7    ┆ 4     ┆ The scene is clean and        │
# │ 607192552                     ┆                ┆         ┆       ┆ balanced with a simple        │
# │                               ┆                ┆         ┆       ┆ centered compo                │
# │ …                             ┆ …              ┆ …       ┆ …     ┆ …                             │
# │ test_fitness_free_trial_20260 ┆ llm            ┆ II-3    ┆ 5     ┆ The provided evidence shows   │
# │ 607173418                     ┆                ┆         ┆       ┆ the context after missing     │
# │                               ┆                ┆         ┆       ┆ info v                        │
# │ test_fitness_free_trial_20260 ┆ llm            ┆ III-3   ┆ 3     ┆ 한국어 카피가 ‘무료 체험,     │
# │ 607173418                     ┆                ┆         ┆       ┆ 지금 예약’처럼 전반적으로     │
# │                               ┆                ┆         ┆       ┆ 프로모션/예약 유도에는        │
# │                               ┆                ┆         ┆       ┆ 적합하지만 ‘감성적인’ 톤을    │
# │ test_fitness_free_trial_20260 ┆ llm            ┆ III-4   ┆ 4     ┆ CTA가 “예약하기”로 명확하고   │
# │ 607173418                     ┆                ┆         ┆       ┆ 행동 지시가 분명하며          │
# │                               ┆                ┆         ┆       ┆ 헤드라인(무료 체험, 지금      │
# │                               ┆                ┆         ┆       ┆ 예약하세요)과도 잘 맞지만     │
# │ test_fitness_free_trial_20260 ┆ llm            ┆ III-5   ┆ 4     ┆ Copy uses a soft emotional    │
# │ 607173418                     ┆                ┆         ┆       ┆ tone with inviting,           │
# │                               ┆                ┆         ┆       ┆ low-friction                  │
# │ test_fitness_free_trial_20260 ┆ llm            ┆ IV-3    ┆ 4     ┆ The spec defines three        │
# │ 607173418                     ┆                ┆         ┆       ┆ appropriate text slots        │
# │                               ┆                ┆         ┆       ┆ (headline, sub                │
# │ test_fitness_free_trial_20260 ┆ llm            ┆ IV-4    ┆ 4     ┆ The evidence specifies clear  │
# │ 607173418                     ┆                ┆         ┆       ┆ headline vs body typography   │
# │                               ┆                ┆         ┆       ┆ wei                           │
# │ test_fitness_free_trial_20260 ┆ llm            ┆ IV-5    ┆ 1     ┆ The evidence includes copy    │
# │ 607173418                     ┆                ┆         ┆       ┆ roles and a layout planner    │
# │                               ┆                ┆         ┆       ┆ templa                        │
# │ test_fitness_free_trial_20260 ┆ llm            ┆ V-3     ┆ 5     ┆ Evidence shows only 4 total   │
# │ 607173418                     ┆                ┆         ┆       ┆ API calls with low estimated  │
# │                               ┆                ┆         ┆       ┆ cos                           │
# │ test_fitness_free_trial_20260 ┆ llm            ┆ V-4     ┆ 5     ┆ The evidence shows            │
# │ 607173418                     ┆                ┆         ┆       ┆ failed_nodes=0 with no        │
# │                               ┆                ┆         ┆       ┆ fallback/retry cal            │
# │ test_fitness_free_trial_20260 ┆ vlm            ┆ III-6   ┆ 2     ┆ The cool blue palette and     │
# │ 607173418                     ┆                ┆         ┆       ┆ clean layout feel somewhat    │
# │                               ┆                ┆         ┆       ┆ functio                       │
# │ test_fitness_free_trial_20260 ┆ vlm            ┆ IV-6    ┆ 1     ┆ The image clearly contains    │
# │ 607173418                     ┆                ┆         ┆       ┆ multiple visible              │
# │                               ┆                ┆         ┆       ┆ character-like s              │
# │ test_fitness_free_trial_20260 ┆ vlm            ┆ IV-7    ┆ 4     ┆ The image has a centered,     │
# │ 607173418                     ┆                ┆         ┆       ┆ balanced composition with no  │
# │                               ┆                ┆         ┆       ┆ obvio                         │
# │ test_fitness_free_trial_20260 ┆ vlm            ┆ IV-8    ┆ 4     ┆ The overlaid Korean text is   │
# │ 607173418                     ┆                ┆         ┆       ┆ large and mostly legible with │
# │                               ┆                ┆         ┆       ┆ st                            │
# │ test_fitness_free_trial_20260 ┆ vlm            ┆ IV-9    ┆ 2     ┆ The ad has readable copy and  │
# │ 607173418                     ┆                ┆         ┆       ┆ a visible CTA, but the        │
# │                               ┆                ┆         ┆       ┆ heavily                       │
# │ test_bespoke_florist_20260606 ┆ llm            ┆ II-1    ┆ 3     ┆ The context accurately        │
# │ 202514                        ┆                ┆         ┆       ┆ identifies the business type  │
# │                               ┆                ┆         ┆       ┆ (flower                       │
# │ test_bespoke_florist_20260606 ┆ llm            ┆ II-2    ┆ 1     ┆ The validator reports         │
# │ 202514                        ┆                ┆         ┆       ┆ missing_fields as an empty    │
# │                               ┆                ┆         ┆       ┆ list even t                   │
# │ test_bespoke_florist_20260606 ┆ llm            ┆ II-3    ┆ 4     ┆ The validator’s updated       │
# │ 202514                        ┆                ┆         ┆       ┆ context remains internally    │
# │                               ┆                ┆         ┆       ┆ consisten                     │
# │ test_bespoke_florist_20260606 ┆ llm            ┆ III-3   ┆ 3     ┆ Tone is partially aligned via │
# │ 202514                        ┆                ┆         ┆       ┆ a premium, concise Korean     │
# │                               ┆                ┆         ┆       ┆ mess                          │
# │ test_bespoke_florist_20260606 ┆ llm            ┆ III-4   ┆ 2     ┆ CTA text is present (“자세히  │
# │ 202514                        ┆                ┆         ┆       ┆ 보기”) but it is generic and  │
# │                               ┆                ┆         ┆       ┆ not cle                       │
# │ test_bespoke_florist_20260606 ┆ llm            ┆ III-5   ┆ 4     ┆ Tone is broadly consistent    │
# │ 202514                        ┆                ┆         ┆       ┆ with a premium brand using    │
# │                               ┆                ┆         ┆       ┆ refine                        │
# │ test_bespoke_florist_20260606 ┆ llm            ┆ IV-3    ┆ 3     ┆ The template defines          │
# │ 202514                        ┆                ┆         ┆       ┆ appropriate distinct slots    │
# │                               ┆                ┆         ┆       ┆ for headline                  │
# │ test_bespoke_florist_20260606 ┆ llm            ┆ IV-4    ┆ 4     ┆ The evidence defines distinct │
# │ 202514                        ┆                ┆         ┆       ┆ headline vs body fonts,       │
# │                               ┆                ┆         ┆       ┆ weight                        │
# │ test_bespoke_florist_20260606 ┆ llm            ┆ IV-5    ┆ 3     ┆ The evidence shows a specific │
# │ 202514                        ┆                ┆         ┆       ┆ text layout template and copy │
# │ test_bespoke_florist_20260606 ┆ llm            ┆ V-3     ┆ 2     ┆ Although the user plan is     │
# │ 202514                        ┆                ┆         ┆       ┆ free, the evidence shows      │
# │                               ┆                ┆         ┆       ┆ fallback_                     │
# │ test_bespoke_florist_20260606 ┆ llm            ┆ V-4     ┆ 5     ┆ Evidence shows failed_nodes=0 │
# │ 202514                        ┆                ┆         ┆       ┆ and no indication of failed   │
# │                               ┆                ┆         ┆       ┆ no                            │
# │ test_bespoke_florist_20260606 ┆ vlm            ┆ III-6   ┆ 2     ┆ The image has a cool, minimal │
# │ 202514                        ┆                ┆         ┆       ┆ corporate look with almost no │
# │ test_bespoke_florist_20260606 ┆ vlm            ┆ IV-6    ┆ 5     ┆ The image appears completely  │
# │ 202514                        ┆                ┆         ┆       ┆ free of any visible text,     │
# │                               ┆                ┆         ┆       ┆ lette                         │
# │ test_bespoke_florist_20260606 ┆ vlm            ┆ IV-7    ┆ 5     ┆ The image is clean and free   │
# │ 202514                        ┆                ┆         ┆       ┆ of obvious distortions, with  │
# │                               ┆                ┆         ┆       ┆ a s                           │
# │ test_bespoke_florist_20260606 ┆ vlm            ┆ IV-8    ┆ 3     ┆ The text is placed away from  │
# │ 202514                        ┆                ┆         ┆       ┆ the subject and generally     │
# │                               ┆                ┆         ┆       ┆ reada                         │
# │ test_bespoke_florist_20260606 ┆ vlm            ┆ IV-9    ┆ 2     ┆ The layout is visually clean  │
# │ 202514                        ┆                ┆         ┆       ┆ but the copy is tiny,         │
# │                               ┆                ┆         ┆       ┆ partially                     │
# └───────────────────────────────┴────────────────┴─────────┴───────┴───────────────────────────────┘

# %% [markdown]
# ### gate_results — auto gates pass/fail

# %%
q(EVAL_DB, '''
  SELECT er.job_id, gr.gate_id, gr.passed,
         SUBSTR(COALESCE(gr.failure_reason,''),1,70) AS failure_reason,
         gr.auto_evaluated
  FROM gate_results gr JOIN eval_runs er ON er.eval_id = gr.eval_id
  ORDER BY er.evaluated_at DESC, gr.gate_id LIMIT 60
''')
# Out:
# shape: (25, 5)
# ┌─────────────────────────────────────────┬─────────┬────────┬────────────────┬────────────────┐
# │ job_id                                  ┆ gate_id ┆ passed ┆ failure_reason ┆ auto_evaluated │
# │ ---                                     ┆ ---     ┆ ---    ┆ ---            ┆ ---            │
# │ str                                     ┆ str     ┆ i64    ┆ str            ┆ i64            │
# ╞═════════════════════════════════════════╪═════════╪════════╪════════════════╪════════════════╡
# │ test_store_grand_open_20260608004905    ┆ III-2   ┆ 1      ┆                ┆ 1              │
# │ test_store_grand_open_20260608004905    ┆ V-1     ┆ 1      ┆                ┆ 1              │
# │ test_store_grand_open_20260608004905    ┆ V-2     ┆ 1      ┆                ┆ 1              │
# │ test_store_grand_open_20260608004905    ┆ VI-1    ┆ 1      ┆                ┆ 1              │
# │ test_store_grand_open_20260608004905    ┆ VI-3    ┆ 1      ┆                ┆ 1              │
# │ test_cafe_iced_americano_20260608000015 ┆ III-2   ┆ 1      ┆                ┆ 1              │
# │ test_cafe_iced_americano_20260608000015 ┆ V-1     ┆ 1      ┆                ┆ 1              │
# │ test_cafe_iced_americano_20260608000015 ┆ V-2     ┆ 1      ┆                ┆ 1              │
# │ test_cafe_iced_americano_20260608000015 ┆ VI-1    ┆ 1      ┆                ┆ 1              │
# │ test_cafe_iced_americano_20260608000015 ┆ VI-3    ┆ 1      ┆                ┆ 1              │
# │ test_store_yearend_gift_20260607192552  ┆ III-2   ┆ 1      ┆                ┆ 1              │
# │ test_store_yearend_gift_20260607192552  ┆ V-1     ┆ 1      ┆                ┆ 1              │
# │ test_store_yearend_gift_20260607192552  ┆ V-2     ┆ 1      ┆                ┆ 1              │
# │ test_store_yearend_gift_20260607192552  ┆ VI-1    ┆ 1      ┆                ┆ 1              │
# │ test_store_yearend_gift_20260607192552  ┆ VI-3    ┆ 1      ┆                ┆ 1              │
# │ test_fitness_free_trial_20260607173418  ┆ III-2   ┆ 1      ┆                ┆ 1              │
# │ test_fitness_free_trial_20260607173418  ┆ V-1     ┆ 1      ┆                ┆ 1              │
# │ test_fitness_free_trial_20260607173418  ┆ V-2     ┆ 1      ┆                ┆ 1              │
# │ test_fitness_free_trial_20260607173418  ┆ VI-1    ┆ 1      ┆                ┆ 1              │
# │ test_fitness_free_trial_20260607173418  ┆ VI-3    ┆ 1      ┆                ┆ 1              │
# │ test_bespoke_florist_20260606202514     ┆ III-2   ┆ 1      ┆                ┆ 1              │
# │ test_bespoke_florist_20260606202514     ┆ V-1     ┆ 1      ┆                ┆ 1              │
# │ test_bespoke_florist_20260606202514     ┆ V-2     ┆ 1      ┆                ┆ 1              │
# │ test_bespoke_florist_20260606202514     ┆ VI-1    ┆ 1      ┆                ┆ 1              │
# │ test_bespoke_florist_20260606202514     ┆ VI-3    ┆ 1      ┆                ┆ 1              │
# └─────────────────────────────────────────┴─────────┴────────┴────────────────┴────────────────┘

# %% [markdown]
# ### domain_scores — aggregated per domain

# %%
q(EVAL_DB, '''
  SELECT er.job_id, ds.domain, ROUND(ds.avg_score,3) AS avg_score,
         ds.weight, ROUND(ds.weighted_contribution,3) AS weighted, ds.item_count
  FROM domain_scores ds JOIN eval_runs er ON er.eval_id = ds.eval_id
  ORDER BY er.evaluated_at DESC, ds.domain LIMIT 60
''')
# Out:
# shape: (20, 6)
# ┌─────────────────────────────────────────┬────────┬───────────┬────────┬──────────┬────────────┐
# │ job_id                                  ┆ domain ┆ avg_score ┆ weight ┆ weighted ┆ item_count │
# │ ---                                     ┆ ---    ┆ ---       ┆ ---    ┆ ---      ┆ ---        │
# │ str                                     ┆ str    ┆ null      ┆ f64    ┆ null     ┆ i64        │
# ╞═════════════════════════════════════════╪════════╪═══════════╪════════╪══════════╪════════════╡
# │ test_store_grand_open_20260608004905    ┆ II     ┆ null      ┆ 0.3    ┆ null     ┆ 0          │
# │ test_store_grand_open_20260608004905    ┆ III    ┆ null      ┆ 0.2    ┆ null     ┆ 0          │
# │ test_store_grand_open_20260608004905    ┆ IV     ┆ null      ┆ 0.3    ┆ null     ┆ 0          │
# │ test_store_grand_open_20260608004905    ┆ V      ┆ null      ┆ 0.1    ┆ null     ┆ 0          │
# │ test_cafe_iced_americano_20260608000015 ┆ II     ┆ null      ┆ 0.3    ┆ null     ┆ 0          │
# │ test_cafe_iced_americano_20260608000015 ┆ III    ┆ null      ┆ 0.2    ┆ null     ┆ 0          │
# │ test_cafe_iced_americano_20260608000015 ┆ IV     ┆ null      ┆ 0.3    ┆ null     ┆ 0          │
# │ test_cafe_iced_americano_20260608000015 ┆ V      ┆ null      ┆ 0.1    ┆ null     ┆ 0          │
# │ test_store_yearend_gift_20260607192552  ┆ II     ┆ null      ┆ 0.3    ┆ null     ┆ 0          │
# │ test_store_yearend_gift_20260607192552  ┆ III    ┆ null      ┆ 0.2    ┆ null     ┆ 0          │
# │ test_store_yearend_gift_20260607192552  ┆ IV     ┆ null      ┆ 0.3    ┆ null     ┆ 0          │
# │ test_store_yearend_gift_20260607192552  ┆ V      ┆ null      ┆ 0.1    ┆ null     ┆ 0          │
# │ test_fitness_free_trial_20260607173418  ┆ II     ┆ null      ┆ 0.3    ┆ null     ┆ 0          │
# │ test_fitness_free_trial_20260607173418  ┆ III    ┆ null      ┆ 0.2    ┆ null     ┆ 0          │
# │ test_fitness_free_trial_20260607173418  ┆ IV     ┆ null      ┆ 0.3    ┆ null     ┆ 0          │
# │ test_fitness_free_trial_20260607173418  ┆ V      ┆ null      ┆ 0.1    ┆ null     ┆ 0          │
# │ test_bespoke_florist_20260606202514     ┆ II     ┆ null      ┆ 0.3    ┆ null     ┆ 0          │
# │ test_bespoke_florist_20260606202514     ┆ III    ┆ null      ┆ 0.2    ┆ null     ┆ 0          │
# │ test_bespoke_florist_20260606202514     ┆ IV     ┆ null      ┆ 0.3    ┆ null     ┆ 0          │
# │ test_bespoke_florist_20260606202514     ┆ V      ┆ null      ┆ 0.1    ┆ null     ┆ 0          │
# └─────────────────────────────────────────┴────────┴───────────┴────────┴──────────┴────────────┘

# %% [markdown]
# ### judge_status — idempotent judge queue (attempts / errors)

# %%
q(EVAL_DB, '''
  SELECT eval_id, evaluator_type, status, attempts,
         SUBSTR(COALESCE(last_error,''),1,70) AS last_error
  FROM judge_status ORDER BY rowid DESC LIMIT 40
''')
# Out:
# shape: (8, 5)
# ┌───────────────────────────────────────┬────────────────┬────────┬──────────┬────────────┐
# │ eval_id                               ┆ evaluator_type ┆ status ┆ attempts ┆ last_error │
# │ ---                                   ┆ ---            ┆ ---    ┆ ---      ┆ ---        │
# │ str                                   ┆ str            ┆ str    ┆ i64      ┆ str        │
# ╞═══════════════════════════════════════╪════════════════╪════════╪══════════╪════════════╡
# │ eval_d7ed198bb9334aa7aeceed61c42b7ffc ┆ vlm            ┆ done   ┆ 1        ┆            │
# │ eval_d7ed198bb9334aa7aeceed61c42b7ffc ┆ llm            ┆ done   ┆ 1        ┆            │
# │ eval_7aa7e6531acb41c0b64d5dcd59e99fb0 ┆ vlm            ┆ done   ┆ 1        ┆            │
# │ eval_7aa7e6531acb41c0b64d5dcd59e99fb0 ┆ llm            ┆ done   ┆ 1        ┆            │
# │ eval_d0babc4546b24504a03587bbfb212329 ┆ vlm            ┆ done   ┆ 1        ┆            │
# │ eval_d0babc4546b24504a03587bbfb212329 ┆ llm            ┆ done   ┆ 1        ┆            │
# │ eval_2b15898d48e74bddbc94c873829d4a3e ┆ vlm            ┆ done   ┆ 1        ┆            │
# │ eval_2b15898d48e74bddbc94c873829d4a3e ┆ llm            ┆ done   ┆ 1        ┆            │
# └───────────────────────────────────────┴────────────────┴────────┴──────────┴────────────┘

# %% [markdown]
# # 일자별 요약 (per-day)
#
# ops/eval DB를 `date()`로 묶어 하루 단위 활동·비용·점수를 본다.

# %% [markdown]
# ### 하루별 생성/비용 (ops) — job 수, plan 구성, T2I 엔진, 토큰, LLM+T2I 비용

# %%
q(OPS_DB, '''
  SELECT date(j.created_at) AS day, COUNT(*) AS jobs,
         SUM(j.user_plan='premium') AS premium, SUM(j.user_plan='free') AS free,
         GROUP_CONCAT(DISTINCT c.t2i_engine) AS engines,
         SUM(c.total_tokens) AS tokens,
         ROUND(SUM(COALESCE(c.total_cost_usd,0)),5) AS gen_usd,
         ROUND(SUM(COALESCE(c.t2i_cost_usd,0)),5) AS t2i_usd
  FROM jobs j LEFT JOIN job_cost_summary c USING(job_id)
  GROUP BY day ORDER BY day DESC
''')
# Out:
# shape: (3, 8)
# ┌────────────┬──────┬─────────┬──────┬────────────┬────────┬─────────┬─────────┐
# │ day        ┆ jobs ┆ premium ┆ free ┆ engines    ┆ tokens ┆ gen_usd ┆ t2i_usd │
# │ ---        ┆ ---  ┆ ---     ┆ ---  ┆ ---        ┆ ---    ┆ ---     ┆ ---     │
# │ str        ┆ i64  ┆ i64     ┆ i64  ┆ str        ┆ i64    ┆ f64     ┆ f64     │
# ╞════════════╪══════╪═════════╪══════╪════════════╪════════╪═════════╪═════════╡
# │ 2026-06-08 ┆ 2    ┆ 1       ┆ 1    ┆ sd35_large ┆ 7874   ┆ 0.0701  ┆ 0.0411  │
# │ 2026-06-07 ┆ 2    ┆ 1       ┆ 1    ┆ sd35_large ┆ 7412   ┆ 0.02958 ┆ 0.0     │
# │ 2026-06-06 ┆ 1    ┆ 0       ┆ 1    ┆ sd35_large ┆ 0      ┆ 0.0     ┆ 0.0     │
# └────────────┴──────┴─────────┴──────┴────────────┴────────┴─────────┴─────────┘

# %% [markdown]
# ### 하루별 평가 점수 (eval) — eval 수, 평균/최저 점수, verdict 분포

# %%
q(EVAL_DB, '''
  SELECT date(evaluated_at) AS day, COUNT(*) AS evals,
         ROUND(AVG(overall_score),2) AS avg_score,
         ROUND(MIN(overall_score),2) AS min_score,
         GROUP_CONCAT(DISTINCT verdict) AS verdicts
  FROM eval_runs GROUP BY day ORDER BY day DESC
''')
# Out:
# shape: (3, 5)
# ┌────────────┬───────┬───────────┬───────────┬───────────────────────────────┐
# │ day        ┆ evals ┆ avg_score ┆ min_score ┆ verdicts                      │
# │ ---        ┆ ---   ┆ ---       ┆ ---       ┆ ---                           │
# │ str        ┆ i64   ┆ f64       ┆ f64       ┆ str                           │
# ╞════════════╪═══════╪═══════════╪═══════════╪═══════════════════════════════╡
# │ 2026-06-08 ┆ 2     ┆ 3.41      ┆ 3.41      ┆ major_revision,pending_scores │
# │ 2026-06-07 ┆ 2     ┆ 3.59      ┆ 3.5       ┆ major_revision                │
# │ 2026-06-06 ┆ 1     ┆ 3.25      ┆ 3.25      ┆ major_revision                │
# └────────────┴───────┴───────────┴───────────┴───────────────────────────────┘

# %% [markdown]
# ### 특정 일자 드릴다운 — `DAY` 지정(빈 값이면 최신 활동일). 그 날의 job · LLM호출 · 점수.

# %%
from IPython.display import display
# DAY='' 면 가장 최근 job이 있는 날짜로 자동
DAY = ''
if not DAY:
    DAY = q(OPS_DB, "SELECT date(MAX(created_at)) FROM jobs")[0, 0]
print('DAY =', DAY)

print('\n— jobs —')
display(q(OPS_DB, '''
  SELECT j.job_id, j.user_plan AS plan, j.status, c.t2i_engine AS engine,
         c.total_tokens AS tok,
         COALESCE(printf('%.6f', c.t2i_cost_usd), c.t2i_cost_source) AS t2i_cost
  FROM jobs j LEFT JOIN job_cost_summary c USING(job_id)
  WHERE date(j.created_at)=? ORDER BY j.created_at''', (DAY,)))

print('\n— llm_calls —')
display(q(OPS_DB, '''
  SELECT job_id, node_name, model_class AS cls, success AS ok,
         fallback_used AS fb, COALESCE(error_code,'') AS err
  FROM llm_calls WHERE date(created_at)=? ORDER BY id''', (DAY,)))

print('\n— eval scores —')
display(q(EVAL_DB, '''
  SELECT job_id, ROUND(overall_score,2) AS score, verdict
  FROM eval_runs WHERE date(evaluated_at)=? ORDER BY evaluated_at''', (DAY,)))
# Out:
# DAY = 2026-06-08
#
# — jobs —
# shape: (2, 6)
# ┌─────────────────────────────────────────┬─────────┬────────┬────────────┬──────┬──────────┐
# │ job_id                                  ┆ plan    ┆ status ┆ engine     ┆ tok  ┆ t2i_cost │
# │ ---                                     ┆ ---     ┆ ---    ┆ ---        ┆ ---  ┆ ---      │
# │ str                                     ┆ str     ┆ str    ┆ str        ┆ i64  ┆ str      │
# ╞═════════════════════════════════════════╪═════════╪════════╪════════════╪══════╪══════════╡
# │ test_cafe_iced_americano_20260608000015 ┆ free    ┆ done   ┆ sd35_large ┆ 0    ┆ 0.019133 │
# │ test_store_grand_open_20260608004905    ┆ premium ┆ done   ┆ sd35_large ┆ 7874 ┆ 0.021963 │
# └─────────────────────────────────────────┴─────────┴────────┴────────────┴──────┴──────────┘
# — llm_calls —
# shape: (7, 6)
# ┌───────────────────────┬───────────────────────┬───────────────┬─────┬─────┬──────────────────────┐
# │ job_id                ┆ node_name             ┆ cls           ┆ ok  ┆ fb  ┆ err                  │
# │ ---                   ┆ ---                   ┆ ---           ┆ --- ┆ --- ┆ ---                  │
# │ str                   ┆ str                   ┆ str           ┆ i64 ┆ i64 ┆ str                  │
# ╞═══════════════════════╪═══════════════════════╪═══════════════╪═════╪═════╪══════════════════════╡
# │ test_cafe_iced_americ ┆ tone_binding          ┆ mock          ┆ 0   ┆ 1   ┆ free_plan_determinis │
# │ ano_20260608000015    ┆                       ┆               ┆     ┆     ┆ tic_fallback         │
# │ test_cafe_iced_americ ┆ copy_candidate_genera ┆ local_quality ┆ 0   ┆ 1   ┆ free_plan_determinis │
# │ ano_20260608000015    ┆ tion                  ┆               ┆     ┆     ┆ tic_fallback         │
# │ test_store_grand_open ┆ validator             ┆ api_mini      ┆ 1   ┆ 0   ┆                      │
# │ _20260608004905       ┆                       ┆               ┆     ┆     ┆                      │
# │ test_store_grand_open ┆ validator             ┆ api_mini      ┆ 1   ┆ 0   ┆                      │
# │ _20260608004905       ┆                       ┆               ┆     ┆     ┆                      │
# │ test_store_grand_open ┆ tone_binding          ┆ api_mini      ┆ 1   ┆ 0   ┆                      │
# │ _20260608004905       ┆                       ┆               ┆     ┆     ┆                      │
# │ test_store_grand_open ┆ copy_candidate_genera ┆ api_mini      ┆ 1   ┆ 0   ┆                      │
# │ _20260608004905       ┆ tion                  ┆               ┆     ┆     ┆                      │
# │ test_store_grand_open ┆ prompt_critic         ┆ api_full      ┆ 1   ┆ 0   ┆                      │
# │ _20260608004905       ┆                       ┆               ┆     ┆     ┆                      │
# └───────────────────────┴───────────────────────┴───────────────┴─────┴─────┴──────────────────────┘
# — eval scores —
# shape: (2, 3)
# ┌─────────────────────────────────────────┬───────┬────────────────┐
# │ job_id                                  ┆ score ┆ verdict        │
# │ ---                                     ┆ ---   ┆ ---            │
# │ str                                     ┆ f64   ┆ str            │
# ╞═════════════════════════════════════════╪═══════╪════════════════╡
# │ test_cafe_iced_americano_20260608000015 ┆ 3.41  ┆ major_revision │
# │ test_store_grand_open_20260608004905    ┆ null  ┆ pending_scores │
# └─────────────────────────────────────────┴───────┴────────────────┘

# %% [markdown]
# ### 파일명/job_id로 이미지 보기
# `show_image(name)` — 전체경로 · 파일명 · job_id 중 무엇이든. `kind='final'`(최종합성) | `'bg'`(배경).

# %%
from IPython.display import Image, display
import glob, os

def show_image(name, kind='final'):
    """이미지 표시. name = 전체경로 | 파일명(final_composite.png 등) | job_id.
    kind: 'final'(최종 광고) | 'bg'(텍스트 없는 배경). job_id일 때만 적용."""
    name = (name or '').strip()
    img_root = os.path.join(RECORDS, 'images')
    cand = []
    if os.path.isfile(name):                                    # 1) 전체경로
        cand = [name]
    else:
        patt = 'final_composite*.png' if kind == 'final' else '*background*.png'
        job_dir = os.path.join(img_root, name)
        if os.path.isdir(job_dir):                              # 2) job_id 폴더
            cand = sorted(glob.glob(os.path.join(job_dir, patt))) or sorted(glob.glob(os.path.join(job_dir, '*.png')))
        if not cand:                                            # 3) 파일명(부분일치) 트리 검색
            cand = sorted(glob.glob(os.path.join(img_root, '**', name), recursive=True)) \
                or sorted(glob.glob(os.path.join(img_root, '**', '*' + name + '*'), recursive=True))
    if not cand:
        print('찾지 못함:', name, '| ', img_root, '아래에서 검색'); return
    for p in cand:
        print(p)
        display(Image(filename=p))

# 사용 예: show_image('test_cafe_iced_americano_20260608000015')  /  show_image('final_composite.png')  /  show_image(<job_id>, kind='bg')
show_image(q(OPS_DB, "SELECT job_id FROM jobs ORDER BY created_at DESC LIMIT 1")[0, 0])
# Out:
# /app/records/images/test_store_grand_open_20260608004905/final_composite.png

# %%
show_image('test_cafe_morning_set_20260608011644')
# Out:
# /app/records/images/test_cafe_morning_set_20260608011644/final_composite.png
