# %% [markdown]
# # eval DB viewer
#
# Read-only look at the two shared SQLite DBs.
#
# - **records (ops DB)** `easyads_ops.db` — jobs / node_executions / llm_calls / schema_validations / job_cost_summary / dirty_field_events
# - **eval DB** `easyads_eval.db` — eval_runs / score_items / gate_results / domain_scores / judge_status
#
# Run the **Setup** cell first, then any cell below. Re-run a cell to refresh (safe to run while `make eval-sample` is generating).
#
# **Validity rule:** a job is real only if every `llm_calls.fallback_used = 0` AND `t2i_engine = gpt_image_2` AND `imgs >= 1`. Any `fallback_used = 1` -> discard that job.

# %% [markdown]
# ## Setup

# %%
import os, sqlite3

# polars(빠른 Rust DataFrame)로 표시. 미설치 환경(호스트 .venv 등)에선 stdlib _Table 폴백 →
# 노트북이 어디서든 hard-fail 안 함. 컨테이너(Dockerfile.eval)엔 polars 포함.
try:
    import polars as pl
    pl.Config.set_tbl_rows(60)
    pl.Config.set_tbl_cols(-1)
    pl.Config.set_fmt_str_lengths(80)
    _HAVE_POLARS = True
except ModuleNotFoundError:
    _HAVE_POLARS = False


class _Table:
    """polars 미설치용 경량 폴백 — q()와 동일 인터페이스([r, c] 인덱싱, len) 유지해
    아래 셀들의 df[0, 0] / len(df) 가 polars 유무와 무관하게 동작."""
    def __init__(self, columns, rows):
        self.columns, self.rows = columns, rows
    def __len__(self):
        return len(self.rows)
    def __getitem__(self, key):
        if isinstance(key, tuple):
            r, c = key
            return self.rows[r][c]
        return self.rows[key]
    def __repr__(self):
        if not self.rows:
            return " | ".join(self.columns) + "\n(0 rows)"
        w = [max([len(str(c))] + [len(str(r[i])) for r in self.rows]) for i, c in enumerate(self.columns)]
        head = " | ".join(str(c).ljust(w[i]) for i, c in enumerate(self.columns))
        sep = "-+-".join("-" * x for x in w)
        body = "\n".join(" | ".join(str(v).ljust(w[i]) for i, v in enumerate(r)) for r in self.rows)
        return f"{head}\n{sep}\n{body}"


# /home/records on host, /app/records inside a container. Override with RECORDS_DIR.
RECORDS = os.environ.get('RECORDS_DIR') or next(
    (p for p in ('/home/records', '/app/records') if os.path.isdir(p)), '/home/records')
OPS_DB  = os.path.join(RECORDS, 'easyads_ops.db')
EVAL_DB = os.path.join(RECORDS, 'easyads_eval.db')


def q(db, sql, params=()):
    """읽기전용 쿼리 실행 → polars DataFrame(있으면) 또는 _Table 폴백."""
    with sqlite3.connect(db) as c:
        cur = c.execute(sql, params)
        rows = [tuple(r) for r in cur.fetchall()]
        cols = [d[0] for d in cur.description]
    if _HAVE_POLARS:
        return pl.DataFrame(rows, schema=cols, orient="row") if rows else pl.DataFrame(schema=cols)
    return _Table(cols, rows)


print('polars  :', 'yes' if _HAVE_POLARS else 'NO (stdlib fallback)')
print('RECORDS :', RECORDS)
print('OPS_DB  :', OPS_DB,  '(exists)' if os.path.isfile(OPS_DB)  else '(MISSING)')
print('EVAL_DB :', EVAL_DB, '(exists)' if os.path.isfile(EVAL_DB) else '(MISSING)')
# Out:
# polars  : yes
# RECORDS : /app/records
# OPS_DB  : /app/records/easyads_ops.db (exists)
# EVAL_DB : /app/records/easyads_eval.db (exists)

# %%
os.getcwd()
# Out:
# '/app/orchestrator/eval'

# %% [markdown]
# # records (ops DB)

# %% [markdown]
# ### jobs — overview (newest first)

# %%
q(OPS_DB, '''
  SELECT job_id, user_plan AS plan, render_profile AS render, status,
         entry_mode, revision, created_at
  FROM jobs ORDER BY created_at DESC LIMIT 30
''')
# Out:
# shape: (5, 7)
# ┌────────────────────┬─────────┬─────────────┬────────┬────────────┬──────────┬────────────────────┐
# │ job_id             ┆ plan    ┆ render      ┆ status ┆ entry_mode ┆ revision ┆ created_at         │
# │ ---                ┆ ---     ┆ ---         ┆ ---    ┆ ---        ┆ ---      ┆ ---                │
# │ str                ┆ str     ┆ str         ┆ str    ┆ str        ┆ i64      ┆ str                │
# ╞════════════════════╪═════════╪═════════════╪════════╪════════════╪══════════╪════════════════════╡
# │ test_bespoke_flori ┆ free    ┆ balanced    ┆ done   ┆ chat_start ┆ 1        ┆ 2026-06-06T20:25:1 │
# │ st_20260606202514  ┆         ┆             ┆        ┆            ┆          ┆ 4.800877+00:00     │
# │ test_store_review_ ┆ free    ┆ balanced    ┆ done   ┆ chat_start ┆ 1        ┆ 2026-06-05T09:05:2 │
# │ event_202606050905 ┆         ┆             ┆        ┆            ┆          ┆ 9.307814+00:00     │
# │ 29                 ┆         ┆             ┆        ┆            ┆          ┆                    │
# │ test_cafe_strawber ┆ free    ┆ balanced    ┆ done   ┆ chat_start ┆ 1        ┆ 2026-06-05T09:01:3 │
# │ ry_latte_new_20260 ┆         ┆             ┆        ┆            ┆          ┆ 1.083150+00:00     │
# │ 605090130          ┆         ┆             ┆        ┆            ┆          ┆                    │
# │ test_store_custom_ ┆ premium ┆ premium_api ┆ done   ┆ chat_start ┆ 1        ┆ 2026-06-05T04:50:2 │
# │ copy_2026060504485 ┆         ┆             ┆        ┆            ┆          ┆ 7.274524+00:00     │
# │ 5                  ┆         ┆             ┆        ┆            ┆          ┆                    │
# │ test_fitness_local ┆ premium ┆ premium_api ┆ done   ┆ chat_start ┆ 1        ┆ 2026-06-05T04:48:5 │
# │ _brand_20260605044 ┆         ┆             ┆        ┆            ┆          ┆ 5.302242+00:00     │
# │ 855                ┆         ┆             ┆        ┆            ┆          ┆                    │
# └────────────────────┴─────────┴─────────────┴────────┴────────────┴──────────┴────────────────────┘

# %% [markdown]
# ### llm_calls — fallback summary per job (fb_total must be 0 for a valid run)

# %%
q(OPS_DB, '''
  SELECT job_id,
         COUNT(*)            AS llm_calls,
         SUM(fallback_used)  AS fb_total,
         SUM(success)        AS ok_total,
         GROUP_CONCAT(DISTINCT error_code) AS errors
  FROM llm_calls GROUP BY job_id ORDER BY job_id DESC LIMIT 30
''')
# Out:
# shape: (5, 5)
# ┌────────────────────────────────┬───────────┬──────────┬──────────┬───────────────────────────────┐
# │ job_id                         ┆ llm_calls ┆ fb_total ┆ ok_total ┆ errors                        │
# │ ---                            ┆ ---       ┆ ---      ┆ ---      ┆ ---                           │
# │ str                            ┆ i64       ┆ i64      ┆ i64      ┆ str                           │
# ╞════════════════════════════════╪═══════════╪══════════╪══════════╪═══════════════════════════════╡
# │ test_store_review_event_202606 ┆ 2         ┆ 2        ┆ 0        ┆ free_plan_deterministic_fallb │
# │ 05090529                       ┆           ┆          ┆          ┆ ack                           │
# │ test_store_custom_copy_2026060 ┆ 4         ┆ 1        ┆ 3        ┆ openai_api_error:ValidationEr │
# │ 5044855                        ┆           ┆          ┆          ┆ ror                           │
# │ test_fitness_local_brand_20260 ┆ 4         ┆ 1        ┆ 3        ┆ openai_api_error:ValidationEr │
# │ 605044855                      ┆           ┆          ┆          ┆ ror                           │
# │ test_cafe_strawberry_latte_new ┆ 2         ┆ 2        ┆ 0        ┆ free_plan_deterministic_fallb │
# │ _20260605090130                ┆           ┆          ┆          ┆ ack                           │
# │ test_bespoke_florist_202606062 ┆ 2         ┆ 2        ┆ 0        ┆ free_plan_deterministic_fallb │
# │ 02514                          ┆           ┆          ┆          ┆ ack                           │
# └────────────────────────────────┴───────────┴──────────┴──────────┴───────────────────────────────┘

# %% [markdown]
# ### llm_calls — per-node detail (model / fallback / error / cost)

# %%
q(OPS_DB, '''
  SELECT job_id, node_name, model_class, model_name,
         success AS ok, fallback_used AS fb,
         COALESCE(error_code,'') AS error_code,
         total_tokens AS tok, cost_usd, cost_source
  FROM llm_calls ORDER BY id DESC LIMIT 60
''')
# Out:
# shape: (14, 10)
# ┌───────────┬───────────┬───────────┬──────────┬─────┬─────┬──────────┬──────┬──────────┬──────────┐
# │ job_id    ┆ node_name ┆ model_cla ┆ model_na ┆ ok  ┆ fb  ┆ error_co ┆ tok  ┆ cost_usd ┆ cost_sou │
# │ ---       ┆ ---       ┆ ss        ┆ me       ┆ --- ┆ --- ┆ de       ┆ ---  ┆ ---      ┆ rce      │
# │ str       ┆ str       ┆ ---       ┆ ---      ┆ i64 ┆ i64 ┆ ---      ┆ i64  ┆ f64      ┆ ---      │
# │           ┆           ┆ str       ┆ str      ┆     ┆     ┆ str      ┆      ┆          ┆ str      │
# ╞═══════════╪═══════════╪═══════════╪══════════╪═════╪═════╪══════════╪══════╪══════════╪══════════╡
# │ test_besp ┆ copy_cand ┆ local_qua ┆ local_qu ┆ 0   ┆ 1   ┆ free_pla ┆ null ┆ 0.0      ┆ self_hos │
# │ oke_flori ┆ idate_gen ┆ lity      ┆ ality    ┆     ┆     ┆ n_determ ┆      ┆          ┆ ted      │
# │ st_202606 ┆ eration   ┆           ┆          ┆     ┆     ┆ inistic_ ┆      ┆          ┆          │
# │ 06202514  ┆           ┆           ┆          ┆     ┆     ┆ fallback ┆      ┆          ┆          │
# │ test_besp ┆ tone_bind ┆ mock      ┆ mock     ┆ 0   ┆ 1   ┆ free_pla ┆ null ┆ 0.0      ┆ adapter  │
# │ oke_flori ┆ ing       ┆           ┆          ┆     ┆     ┆ n_determ ┆      ┆          ┆          │
# │ st_202606 ┆           ┆           ┆          ┆     ┆     ┆ inistic_ ┆      ┆          ┆          │
# │ 06202514  ┆           ┆           ┆          ┆     ┆     ┆ fallback ┆      ┆          ┆          │
# │ test_stor ┆ copy_cand ┆ local_qua ┆ local_qu ┆ 0   ┆ 1   ┆ free_pla ┆ null ┆ 0.0      ┆ self_hos │
# │ e_review_ ┆ idate_gen ┆ lity      ┆ ality    ┆     ┆     ┆ n_determ ┆      ┆          ┆ ted      │
# │ event_202 ┆ eration   ┆           ┆          ┆     ┆     ┆ inistic_ ┆      ┆          ┆          │
# │ 606050905 ┆           ┆           ┆          ┆     ┆     ┆ fallback ┆      ┆          ┆          │
# │ 29        ┆           ┆           ┆          ┆     ┆     ┆          ┆      ┆          ┆          │
# │ test_stor ┆ tone_bind ┆ mock      ┆ mock     ┆ 0   ┆ 1   ┆ free_pla ┆ null ┆ 0.0      ┆ adapter  │
# │ e_review_ ┆ ing       ┆           ┆          ┆     ┆     ┆ n_determ ┆      ┆          ┆          │
# │ event_202 ┆           ┆           ┆          ┆     ┆     ┆ inistic_ ┆      ┆          ┆          │
# │ 606050905 ┆           ┆           ┆          ┆     ┆     ┆ fallback ┆      ┆          ┆          │
# │ 29        ┆           ┆           ┆          ┆     ┆     ┆          ┆      ┆          ┆          │
# │ test_cafe ┆ copy_cand ┆ local_qua ┆ local_qu ┆ 0   ┆ 1   ┆ free_pla ┆ null ┆ 0.0      ┆ self_hos │
# │ _strawber ┆ idate_gen ┆ lity      ┆ ality    ┆     ┆     ┆ n_determ ┆      ┆          ┆ ted      │
# │ ry_latte_ ┆ eration   ┆           ┆          ┆     ┆     ┆ inistic_ ┆      ┆          ┆          │
# │ new_20260 ┆           ┆           ┆          ┆     ┆     ┆ fallback ┆      ┆          ┆          │
# │ 605090130 ┆           ┆           ┆          ┆     ┆     ┆          ┆      ┆          ┆          │
# │ test_cafe ┆ tone_bind ┆ mock      ┆ mock     ┆ 0   ┆ 1   ┆ free_pla ┆ null ┆ 0.0      ┆ adapter  │
# │ _strawber ┆ ing       ┆           ┆          ┆     ┆     ┆ n_determ ┆      ┆          ┆          │
# │ ry_latte_ ┆           ┆           ┆          ┆     ┆     ┆ inistic_ ┆      ┆          ┆          │
# │ new_20260 ┆           ┆           ┆          ┆     ┆     ┆ fallback ┆      ┆          ┆          │
# │ 605090130 ┆           ┆           ┆          ┆     ┆     ┆          ┆      ┆          ┆          │
# │ test_stor ┆ prompt_cr ┆ api_full  ┆ api_full ┆ 0   ┆ 1   ┆ openai_a ┆ null ┆ null     ┆ usage_mi │
# │ e_custom_ ┆ itic      ┆           ┆          ┆     ┆     ┆ pi_error ┆      ┆          ┆ ssing    │
# │ copy_2026 ┆           ┆           ┆          ┆     ┆     ┆ :Validat ┆      ┆          ┆          │
# │ 060504485 ┆           ┆           ┆          ┆     ┆     ┆ ionError ┆      ┆          ┆          │
# │ 5         ┆           ┆           ┆          ┆     ┆     ┆          ┆      ┆          ┆          │
# │ test_stor ┆ tone_bind ┆ api_mini  ┆ api_mini ┆ 1   ┆ 0   ┆          ┆ 1349 ┆ 0.003145 ┆ exact    │
# │ e_custom_ ┆ ing       ┆           ┆          ┆     ┆     ┆          ┆      ┆ 5        ┆          │
# │ copy_2026 ┆           ┆           ┆          ┆     ┆     ┆          ┆      ┆          ┆          │
# │ 060504485 ┆           ┆           ┆          ┆     ┆     ┆          ┆      ┆          ┆          │
# │ 5         ┆           ┆           ┆          ┆     ┆     ┆          ┆      ┆          ┆          │
# │ test_stor ┆ validator ┆ api_mini  ┆ api_mini ┆ 1   ┆ 0   ┆          ┆ 641  ┆ 0.001017 ┆ exact    │
# │ e_custom_ ┆           ┆           ┆          ┆     ┆     ┆          ┆      ┆          ┆          │
# │ copy_2026 ┆           ┆           ┆          ┆     ┆     ┆          ┆      ┆          ┆          │
# │ 060504485 ┆           ┆           ┆          ┆     ┆     ┆          ┆      ┆          ┆          │
# │ 5         ┆           ┆           ┆          ┆     ┆     ┆          ┆      ┆          ┆          │
# │ test_stor ┆ validator ┆ api_mini  ┆ api_mini ┆ 1   ┆ 0   ┆          ┆ 597  ┆ 0.000845 ┆ exact    │
# │ e_custom_ ┆           ┆           ┆          ┆     ┆     ┆          ┆      ┆          ┆          │
# │ copy_2026 ┆           ┆           ┆          ┆     ┆     ┆          ┆      ┆          ┆          │
# │ 060504485 ┆           ┆           ┆          ┆     ┆     ┆          ┆      ┆          ┆          │
# │ 5         ┆           ┆           ┆          ┆     ┆     ┆          ┆      ┆          ┆          │
# │ test_fitn ┆ prompt_cr ┆ api_full  ┆ api_full ┆ 0   ┆ 1   ┆ openai_a ┆ null ┆ null     ┆ usage_mi │
# │ ess_local ┆ itic      ┆           ┆          ┆     ┆     ┆ pi_error ┆      ┆          ┆ ssing    │
# │ _brand_20 ┆           ┆           ┆          ┆     ┆     ┆ :Validat ┆      ┆          ┆          │
# │ 260605044 ┆           ┆           ┆          ┆     ┆     ┆ ionError ┆      ┆          ┆          │
# │ 855       ┆           ┆           ┆          ┆     ┆     ┆          ┆      ┆          ┆          │
# │ test_fitn ┆ copy_cand ┆ api_mini  ┆ api_mini ┆ 1   ┆ 0   ┆          ┆ 3397 ┆ 0.005206 ┆ exact    │
# │ ess_local ┆ idate_gen ┆           ┆          ┆     ┆     ┆          ┆      ┆ 5        ┆          │
# │ _brand_20 ┆ eration   ┆           ┆          ┆     ┆     ┆          ┆      ┆          ┆          │
# │ 260605044 ┆           ┆           ┆          ┆     ┆     ┆          ┆      ┆          ┆          │
# │ 855       ┆           ┆           ┆          ┆     ┆     ┆          ┆      ┆          ┆          │
# │ test_fitn ┆ tone_bind ┆ api_mini  ┆ api_mini ┆ 1   ┆ 0   ┆          ┆ 1285 ┆ 0.002846 ┆ exact    │
# │ ess_local ┆ ing       ┆           ┆          ┆     ┆     ┆          ┆      ┆          ┆          │
# │ _brand_20 ┆           ┆           ┆          ┆     ┆     ┆          ┆      ┆          ┆          │
# │ 260605044 ┆           ┆           ┆          ┆     ┆     ┆          ┆      ┆          ┆          │
# │ 855       ┆           ┆           ┆          ┆     ┆     ┆          ┆      ┆          ┆          │
# │ test_fitn ┆ validator ┆ api_mini  ┆ api_mini ┆ 1   ┆ 0   ┆          ┆ 611  ┆ 0.000923 ┆ exact    │
# │ ess_local ┆           ┆           ┆          ┆     ┆     ┆          ┆      ┆          ┆          │
# │ _brand_20 ┆           ┆           ┆          ┆     ┆     ┆          ┆      ┆          ┆          │
# │ 260605044 ┆           ┆           ┆          ┆     ┆     ┆          ┆      ┆          ┆          │
# │ 855       ┆           ┆           ┆          ┆     ┆     ┆          ┆      ┆          ┆          │
# └───────────┴───────────┴───────────┴──────────┴─────┴─────┴──────────┴──────┴──────────┴──────────┘

# %% [markdown]
# ### node_executions — status & latency (t2i_generation dominates wall time)

# %%
# set a job_id to focus, or leave '' for the latest job
JOB_ID = ''
if not JOB_ID:
    JOB_ID = q(OPS_DB, 'SELECT job_id FROM jobs ORDER BY created_at DESC LIMIT 1')[0, 0]
print('JOB_ID =', JOB_ID)
q(OPS_DB, '''
  SELECT node_name, status, latency_ms AS ms,
         SUBSTR(COALESCE(error_message,''),1,50) AS err
  FROM node_executions WHERE job_id=? ORDER BY id
''', (JOB_ID,))
# Out:
# JOB_ID = test_bespoke_florist_20260606202514
# shape: (29, 4)
# ┌────────────────────────────────────┬───────────┬───────┬─────┐
# │ node_name                          ┆ status    ┆ ms    ┆ err │
# │ ---                                ┆ ---       ┆ ---   ┆ --- │
# │ str                                ┆ str       ┆ i64   ┆ str │
# ╞════════════════════════════════════╪═══════════╪═══════╪═════╡
# │ input                              ┆ completed ┆ 30    ┆     │
# │ validator                          ┆ completed ┆ 5     ┆     │
# │ options                            ┆ started   ┆ null  ┆     │
# │ options                            ┆ completed ┆ 4     ┆     │
# │ state_update                       ┆ completed ┆ 4     ┆     │
# │ validator                          ┆ completed ┆ 4     ┆     │
# │ options                            ┆ started   ┆ null  ┆     │
# │ options                            ┆ completed ┆ 5     ┆     │
# │ state_update                       ┆ completed ┆ 4     ┆     │
# │ validator                          ┆ completed ┆ 4     ┆     │
# │ format_planner                     ┆ completed ┆ 6     ┆     │
# │ tone_binding                       ┆ completed ┆ 10    ┆     │
# │ copy_candidate_generation          ┆ completed ┆ 21    ┆     │
# │ copy_candidate_selection_interrupt ┆ started   ┆ null  ┆     │
# │ copy_candidate_selection_interrupt ┆ completed ┆ 4     ┆     │
# │ state_update_selected_copy         ┆ completed ┆ 4     ┆     │
# │ copy_spec_parser                   ┆ completed ┆ 10    ┆     │
# │ text_style_binder                  ┆ completed ┆ 5     ┆     │
# │ text_layout_planner                ┆ completed ┆ 4     ┆     │
# │ image_prompt_planner               ┆ completed ┆ 5     ┆     │
# │ prompt_renderer                    ┆ completed ┆ 10    ┆     │
# │ t2i_request_builder                ┆ completed ┆ 7     ┆     │
# │ t2i_generation                     ┆ completed ┆ 96344 ┆     │
# │ background_validation              ┆ completed ┆ 14    ┆     │
# │ safe_area_gate                     ┆ completed ┆ 4     ┆     │
# │ text_renderer                      ┆ completed ┆ 281   ┆     │
# │ readability_gate                   ┆ completed ┆ 67    ┆     │
# │ final_validation                   ┆ completed ┆ 11    ┆     │
# │ result                             ┆ completed ┆ 4     ┆     │
# └────────────────────────────────────┴───────────┴───────┴─────┘

# %% [markdown]
# ### job_cost_summary — tokens, USD, T2I engine & image cost

# %%
q(OPS_DB, '''
  SELECT job_id, total_api_calls AS api, fallback_calls AS fb,
         total_tokens AS tok, total_cost_usd AS usd,
         t2i_engine, t2i_image_count AS imgs, t2i_cost_usd, t2i_cost_source,
         cost_estimated AS est
  FROM job_cost_summary ORDER BY rowid DESC LIMIT 30
''')
# Out:
# shape: (5, 10)
# ┌─────────────┬─────┬─────┬──────┬──────────┬─────────────┬──────┬─────────────┬─────────────┬─────┐
# │ job_id      ┆ api ┆ fb  ┆ tok  ┆ usd      ┆ t2i_engine  ┆ imgs ┆ t2i_cost_us ┆ t2i_cost_so ┆ est │
# │ ---         ┆ --- ┆ --- ┆ ---  ┆ ---      ┆ ---         ┆ ---  ┆ d           ┆ urce        ┆ --- │
# │ str         ┆ i64 ┆ i64 ┆ i64  ┆ f64      ┆ str         ┆ i64  ┆ ---         ┆ ---         ┆ i64 │
# │             ┆     ┆     ┆      ┆          ┆             ┆      ┆ f64         ┆ str         ┆     │
# ╞═════════════╪═════╪═════╪══════╪══════════╪═════════════╪══════╪═════════════╪═════════════╪═════╡
# │ test_bespok ┆ 0   ┆ 2   ┆ 0    ┆ 0.0      ┆ sd35_large  ┆ 1    ┆ null        ┆ engine_unkn ┆ 1   │
# │ e_florist_2 ┆     ┆     ┆      ┆          ┆             ┆      ┆             ┆ own         ┆     │
# │ 02606062025 ┆     ┆     ┆      ┆          ┆             ┆      ┆             ┆             ┆     │
# │ 14          ┆     ┆     ┆      ┆          ┆             ┆      ┆             ┆             ┆     │
# │ test_store_ ┆ 0   ┆ 2   ┆ 0    ┆ 0.0      ┆ mock        ┆ 1    ┆ 0.0         ┆ exact       ┆ 0   │
# │ review_even ┆     ┆     ┆      ┆          ┆             ┆      ┆             ┆             ┆     │
# │ t_202606050 ┆     ┆     ┆      ┆          ┆             ┆      ┆             ┆             ┆     │
# │ 90529       ┆     ┆     ┆      ┆          ┆             ┆      ┆             ┆             ┆     │
# │ test_cafe_s ┆ 0   ┆ 2   ┆ 0    ┆ 0.0      ┆ mock        ┆ 1    ┆ 0.0         ┆ exact       ┆ 0   │
# │ trawberry_l ┆     ┆     ┆      ┆          ┆             ┆      ┆             ┆             ┆     │
# │ atte_new_20 ┆     ┆     ┆      ┆          ┆             ┆      ┆             ┆             ┆     │
# │ 26060509013 ┆     ┆     ┆      ┆          ┆             ┆      ┆             ┆             ┆     │
# │ 0           ┆     ┆     ┆      ┆          ┆             ┆      ┆             ┆             ┆     │
# │ test_store_ ┆ 4   ┆ 1   ┆ 2587 ┆ 0.045008 ┆ gpt_image_2 ┆ 1    ┆ 0.04        ┆ exact       ┆ 1   │
# │ custom_copy ┆     ┆     ┆      ┆          ┆             ┆      ┆             ┆             ┆     │
# │ _2026060504 ┆     ┆     ┆      ┆          ┆             ┆      ┆             ┆             ┆     │
# │ 4855        ┆     ┆     ┆      ┆          ┆             ┆      ┆             ┆             ┆     │
# │ test_fitnes ┆ 4   ┆ 1   ┆ 5293 ┆ 0.048976 ┆ gpt_image_2 ┆ 1    ┆ 0.04        ┆ exact       ┆ 1   │
# │ s_local_bra ┆     ┆     ┆      ┆          ┆             ┆      ┆             ┆             ┆     │
# │ nd_20260605 ┆     ┆     ┆      ┆          ┆             ┆      ┆             ┆             ┆     │
# │ 044855      ┆     ┆     ┆      ┆          ┆             ┆      ┆             ┆             ┆     │
# └─────────────┴─────┴─────┴──────┴──────────┴─────────────┴──────┴─────────────┴─────────────┴─────┘

# %% [markdown]
# ### images — generated file paths (result node)

# %%
q(OPS_DB, '''
  SELECT ne.job_id,
         json_extract(nso.output_snapshot,'$.result_payload.output_path')           AS final_ad,
         json_extract(nso.output_snapshot,'$.result_payload.background_image_path')  AS background
  FROM node_state_outputs nso
  JOIN node_executions ne ON ne.id = nso.node_exec_id
  WHERE ne.node_name='result'
  GROUP BY ne.job_id ORDER BY ne.id DESC LIMIT 30
''')
# Out:
# shape: (5, 3)
# ┌────────────────────────────────┬────────────────────────────────┬────────────────────────────────┐
# │ job_id                         ┆ final_ad                       ┆ background                     │
# │ ---                            ┆ ---                            ┆ ---                            │
# │ str                            ┆ str                            ┆ str                            │
# ╞════════════════════════════════╪════════════════════════════════╪════════════════════════════════╡
# │ test_bespoke_florist_202606062 ┆ /app/records/images/test_bespo ┆ /app/records/images/test_bespo │
# │ 02514                          ┆ ke_florist_20260606202514/fina ┆ ke_florist_20260606202514/sd35 │
# │                                ┆ l_composite.png                ┆ _large_0.png                   │
# │ test_store_review_event_202606 ┆ /app/records/images/test_store ┆ /app/records/images/test_store │
# │ 05090529                       ┆ _review_event_20260605090529/f ┆ _review_event_20260605090529/m │
# │                                ┆ inal_composite.png             ┆ ock_0.png                      │
# │ test_cafe_strawberry_latte_new ┆ /app/records/images/test_cafe_ ┆ /app/records/images/test_cafe_ │
# │ _20260605090130                ┆ strawberry_latte_new_202606050 ┆ strawberry_latte_new_202606050 │
# │                                ┆ 90130/final_composit…          ┆ 90130/mock_0.png               │
# │ test_store_custom_copy_2026060 ┆ /app/records/images/test_store ┆ /app/records/images/test_store │
# │ 5044855                        ┆ _custom_copy_20260605044855/fi ┆ _custom_copy_20260605044855/gp │
# │                                ┆ nal_composite.png              ┆ t_image_2_0.png                │
# │ test_fitness_local_brand_20260 ┆ /app/records/images/test_fitne ┆ /app/records/images/test_fitne │
# │ 605044855                      ┆ ss_local_brand_20260605044855/ ┆ ss_local_brand_20260605044855/ │
# │                                ┆ final_composite.png            ┆ gpt_image_2_0.png              │
# └────────────────────────────────┴────────────────────────────────┴────────────────────────────────┘

# %% [markdown]
# ### schema_validations — failures only (empty = all passed)

# %%
q(OPS_DB, '''
  SELECT job_id, node_name, schema_name, field_name,
         SUBSTR(COALESCE(error_detail,''),1,80) AS err
  FROM schema_validations WHERE passed=0 ORDER BY id DESC LIMIT 50
''')
# Out:
# shape: (4, 5)
# ┌───────────────────┬───────────────────┬───────────────────┬───────────────────┬──────────────────┐
# │ job_id            ┆ node_name         ┆ schema_name       ┆ field_name        ┆ err              │
# │ ---               ┆ ---               ┆ ---               ┆ ---               ┆ ---              │
# │ str               ┆ str               ┆ str               ┆ str               ┆ str              │
# ╞═══════════════════╪═══════════════════╪═══════════════════╪═══════════════════╪══════════════════╡
# │ test_bespoke_flor ┆ copy_candidate_ge ┆ CopywritingOutput ┆ copywriting_outpu ┆ 1 validation     │
# │ ist_2026060620251 ┆ neration          ┆                   ┆ t                 ┆ error for Copywr │
# │ 4                 ┆                   ┆                   ┆                   ┆ itingOutput      │
# │                   ┆                   ┆                   ┆                   ┆ marketing_copy   │
# │                   ┆                   ┆                   ┆                   ┆ Field required   │
# │                   ┆                   ┆                   ┆                   ┆ [type=m          │
# │ test_store_review ┆ copy_candidate_ge ┆ CopywritingOutput ┆ copywriting_outpu ┆ 1 validation     │
# │ _event_2026060509 ┆ neration          ┆                   ┆ t                 ┆ error for Copywr │
# │ 0529              ┆                   ┆                   ┆                   ┆ itingOutput      │
# │                   ┆                   ┆                   ┆                   ┆ marketing_copy   │
# │                   ┆                   ┆                   ┆                   ┆ Field required   │
# │                   ┆                   ┆                   ┆                   ┆ [type=m          │
# │ test_cafe_strawbe ┆ copy_candidate_ge ┆ CopywritingOutput ┆ copywriting_outpu ┆ 1 validation     │
# │ rry_latte_new_202 ┆ neration          ┆                   ┆ t                 ┆ error for Copywr │
# │ 60605090130       ┆                   ┆                   ┆                   ┆ itingOutput      │
# │                   ┆                   ┆                   ┆                   ┆ marketing_copy   │
# │                   ┆                   ┆                   ┆                   ┆ Field required   │
# │                   ┆                   ┆                   ┆                   ┆ [type=m          │
# │ test_fitness_loca ┆ copy_candidate_ge ┆ CopywritingOutput ┆ copywriting_outpu ┆ 1 validation     │
# │ l_brand_202606050 ┆ neration          ┆                   ┆ t                 ┆ error for Copywr │
# │ 44855             ┆                   ┆                   ┆                   ┆ itingOutput      │
# │                   ┆                   ┆                   ┆                   ┆ marketing_copy   │
# │                   ┆                   ┆                   ┆                   ┆ Field required   │
# │                   ┆                   ┆                   ┆                   ┆ [type=m          │
# └───────────────────┴───────────────────┴───────────────────┴───────────────────┴──────────────────┘

# %% [markdown]
# ### preview a generated image (optional)

# %%
from IPython.display import Image, display
row = q(OPS_DB, '''
  SELECT json_extract(nso.output_snapshot,'$.result_payload.output_path') AS final_ad
  FROM node_state_outputs nso JOIN node_executions ne ON ne.id=nso.node_exec_id
  WHERE ne.node_name='result' ORDER BY ne.id DESC LIMIT 1
''')
path = row[0, 0] if len(row) else None
print('path:', path)
if path and os.path.isfile(path):
    display(Image(filename=path))
else:
    print('file not reachable from here (may be a container path); open it directly.')
# Out:
# path: /app/records/images/test_bespoke_florist_20260606202514/final_composite.png
# file not reachable from here (may be a container path); open it directly.

# %% [markdown]
# # eval DB

# %% [markdown]
# ### eval_runs — overall score & verdict

# %%
q(EVAL_DB, '''
  SELECT job_id, eval_id, ROUND(overall_score,3) AS score, verdict,
         evaluator_id, evaluated_at
  FROM eval_runs ORDER BY evaluated_at DESC LIMIT 30
''')
# Out:
# job_id                                        | eval_id                               | score | verdict        | evaluator_id | evaluated_at
# ----------------------------------------------+---------------------------------------+-------+----------------+--------------+---------------------------------
# test_bespoke_florist_20260606202514           | eval_d7ed198bb9334aa7aeceed61c42b7ffc | None  | pending_scores | None         | 2026-06-06T20:26:52.107689+00:00
# test_store_review_event_20260605090529        | eval_dc563401a4ba40f2a33b7cdb039cdf8b | None  | pending_scores | None         | 2026-06-05T09:05:30.054583+00:00
# test_cafe_strawberry_latte_new_20260605090130 | eval_331b7eb4046543dd9aa57501473bf51c | None  | pending_scores | None         | 2026-06-05T09:01:31.702749+00:00
# test_store_custom_copy_20260605044855         | eval_74caaee4b10f4ed981944eef40578069 | 3.83  | major_revision | None         | 2026-06-05T04:51:58.768395+00:00
# test_fitness_local_brand_20260605044855       | eval_55f28887cc7347ff82106008896a0d4e | 3.685 | major_revision | None         | 2026-06-05T04:50:27.229686+00:00

# %% [markdown]
# ### score_items — per-item scores by evaluator (llm / vlm / human)

# %%
q(EVAL_DB, '''
  SELECT er.job_id, si.evaluator_type, si.item_id, si.score,
         SUBSTR(COALESCE(si.notes,''),1,60) AS notes
  FROM score_items si JOIN eval_runs er ON er.eval_id = si.eval_id
  ORDER BY er.evaluated_at DESC, si.evaluator_type, si.item_id LIMIT 80
''')
# Out:
# job_id                                  | evaluator_type | item_id | score | notes
# ----------------------------------------+----------------+---------+-------+-------------------------------------------------------------
# test_store_custom_copy_20260605044855   | human          | II-1    | 5     | independent human (smoke)
# test_store_custom_copy_20260605044855   | human          | II-2    | 3     | independent human (smoke)
# test_store_custom_copy_20260605044855   | human          | II-3    | 4     | independent human (smoke)
# test_store_custom_copy_20260605044855   | human          | III-3   | 4     | independent human (smoke)
# test_store_custom_copy_20260605044855   | human          | III-4   | 3     | independent human (smoke)
# test_store_custom_copy_20260605044855   | human          | III-5   | 2     | independent human (smoke)
# test_store_custom_copy_20260605044855   | human          | IV-3    | 4     | independent human (smoke)
# test_store_custom_copy_20260605044855   | human          | IV-4    | 3     | independent human (smoke)
# test_store_custom_copy_20260605044855   | human          | IV-5    | 4     | independent human (smoke)
# test_store_custom_copy_20260605044855   | human          | IV-8    | 2     | independent human (smoke)
# test_store_custom_copy_20260605044855   | human          | IV-9    | 2     | independent human (smoke)
# test_store_custom_copy_20260605044855   | human          | V-3     | 5     | independent human (smoke)
# test_store_custom_copy_20260605044855   | human          | V-4     | 5     | independent human (smoke)
# test_store_custom_copy_20260605044855   | llm            | II-1    | 4     | The extracted context captures the business type (store), pr
# test_store_custom_copy_20260605044855   | llm            | II-2    | 2     | The validator reports missing_fields as empty despite many c
# test_store_custom_copy_20260605044855   | llm            | II-3    | 5     | The validator output context matches the updated context exa
# test_store_custom_copy_20260605044855   | llm            | III-3   | 5     | 제공된 증거는 매장 신상 공지형(직접적·간결·과장 없이 제품/매장 중심)과 Instagram 피드 타깃에 맞
# test_store_custom_copy_20260605044855   | llm            | III-5   | 1     | No actual ad copy text is provided to assess whether it matc
# test_store_custom_copy_20260605044855   | llm            | IV-3    | 5     | The template includes dedicated slots for a top centered hea
# test_store_custom_copy_20260605044855   | llm            | IV-4    | 4     | The evidence specifies distinct headline vs body font famili
# test_store_custom_copy_20260605044855   | llm            | IV-5    | 3     | The evidence shows a defined layout template with a safe-mar
# test_store_custom_copy_20260605044855   | llm            | V-3     | 4     | The usage appears proportionate with only 4 total API calls
# test_store_custom_copy_20260605044855   | llm            | V-4     | 5     | The evidence shows failed_nodes=0, indicating the pipeline c
# test_store_custom_copy_20260605044855   | vlm            | III-6   | 5     | The soft neutral palette, clean styling, and warm natural li
# test_store_custom_copy_20260605044855   | vlm            | IV-6    | 5     | The image appears completely free of any visible text, lette
# test_store_custom_copy_20260605044855   | vlm            | IV-7    | 5     | The scene is clean and well-balanced with a clear focal poin
# test_store_custom_copy_20260605044855   | vlm            | IV-8    | 2     | The copy appears extremely tiny and hard to read, though it
# test_store_custom_copy_20260605044855   | vlm            | IV-9    | 2     | The image has attractive styling and composition, but the te
# test_fitness_local_brand_20260605044855 | human          | II-1    | 5     | independent human (smoke)
# test_fitness_local_brand_20260605044855 | human          | II-2    | 3     | independent human (smoke)
# test_fitness_local_brand_20260605044855 | human          | II-3    | 4     | independent human (smoke)
# test_fitness_local_brand_20260605044855 | human          | III-3   | 4     | independent human (smoke)
# test_fitness_local_brand_20260605044855 | human          | III-4   | 3     | independent human (smoke)
# test_fitness_local_brand_20260605044855 | human          | III-5   | 2     | independent human (smoke)
# test_fitness_local_brand_20260605044855 | human          | IV-3    | 4     | independent human (smoke)
# test_fitness_local_brand_20260605044855 | human          | IV-4    | 3     | independent human (smoke)
# test_fitness_local_brand_20260605044855 | human          | IV-5    | 4     | independent human (smoke)
# test_fitness_local_brand_20260605044855 | human          | IV-8    | 2     | independent human (smoke)
# test_fitness_local_brand_20260605044855 | human          | IV-9    | 2     | independent human (smoke)
# test_fitness_local_brand_20260605044855 | human          | V-3     | 5     | independent human (smoke)
# test_fitness_local_brand_20260605044855 | human          | V-4     | 5     | independent human (smoke)
# test_fitness_local_brand_20260605044855 | llm            | II-1    | 4     | The context accurately identifies the business type (fitness
# test_fitness_local_brand_20260605044855 | llm            | II-2    | 2     | The validator reports missing_fields as empty and confidence
# test_fitness_local_brand_20260605044855 | llm            | II-3    | 5     | The context after the supposed missing-info update remains f
# test_fitness_local_brand_20260605044855 | llm            | III-3   | 4     | 감성적인 톤에 맞게 '가볍게'와 '부담 없이' 등 부드럽고 친근한 문구로 구성되어 있으나, 타깃 페르소나나
# test_fitness_local_brand_20260605044855 | llm            | III-4   | 4     | CTA ‘자세히 보기’ is present and actionable, but it is somewhat g
# test_fitness_local_brand_20260605044855 | llm            | III-5   | 4     | Copy uses a warm, casual, “감성적인” vibe (“가볍게 시작”, “부담 없이 들르기
# test_fitness_local_brand_20260605044855 | llm            | IV-3    | 4     | The spec defines appropriate slots for a top headline, cente
# test_fitness_local_brand_20260605044855 | llm            | IV-4    | 3     | The evidence specifies headline and body font families, weig
# test_fitness_local_brand_20260605044855 | llm            | IV-5    | 3     | Copy roles are present and a reasonable template with safe_m
# test_fitness_local_brand_20260605044855 | llm            | V-3     | 4     | Only 4 total API calls (1 fallback) were made with low estim
# test_fitness_local_brand_20260605044855 | llm            | V-4     | 4     | The evidence shows failed_nodes=0, indicating no failed node
# test_fitness_local_brand_20260605044855 | vlm            | III-6   | 3     | The clean gym setting and equipment fit a fitness brand, but
# test_fitness_local_brand_20260605044855 | vlm            | IV-6    | 5     | The gym scene appears completely free of any visible text, l
# test_fitness_local_brand_20260605044855 | vlm            | IV-7    | 5     | The gym scene is clean and realistic with no visible distort
# test_fitness_local_brand_20260605044855 | vlm            | IV-8    | 2     | The tiny overlaid text is largely unreadable and the bottom
# test_fitness_local_brand_20260605044855 | vlm            | IV-9    | 2     | The gym scene looks polished, but the visible text is tiny a

# %% [markdown]
# ### gate_results — auto gates pass/fail

# %%
q(EVAL_DB, '''
  SELECT er.job_id, gr.gate_id, gr.passed,
         SUBSTR(COALESCE(gr.failure_reason,''),1,70) AS failure_reason,
         gr.auto_evaluated
  FROM gate_results gr JOIN eval_runs er ON er.eval_id = gr.eval_id
  ORDER BY er.evaluated_at DESC, gr.gate_id LIMIT 60
''')
# Out:
# job_id                                        | gate_id | passed | failure_reason | auto_evaluated
# ----------------------------------------------+---------+--------+----------------+---------------
# test_bespoke_florist_20260606202514           | III-2   | 1      |                | 1
# test_bespoke_florist_20260606202514           | V-1     | 1      |                | 1
# test_bespoke_florist_20260606202514           | V-2     | 1      |                | 1
# test_bespoke_florist_20260606202514           | VI-1    | 1      |                | 1
# test_bespoke_florist_20260606202514           | VI-3    | 1      |                | 1
# test_store_review_event_20260605090529        | III-2   | 1      |                | 1
# test_store_review_event_20260605090529        | V-1     | 1      |                | 1
# test_store_review_event_20260605090529        | V-2     | 1      |                | 1
# test_store_review_event_20260605090529        | VI-1    | 1      |                | 1
# test_store_review_event_20260605090529        | VI-3    | 1      |                | 1
# test_cafe_strawberry_latte_new_20260605090130 | III-2   | 1      |                | 1
# test_cafe_strawberry_latte_new_20260605090130 | V-1     | 1      |                | 1
# test_cafe_strawberry_latte_new_20260605090130 | V-2     | 1      |                | 1
# test_cafe_strawberry_latte_new_20260605090130 | VI-1    | 1      |                | 1
# test_cafe_strawberry_latte_new_20260605090130 | VI-3    | 1      |                | 1
# test_store_custom_copy_20260605044855         | III-2   | 1      |                | 1
# test_store_custom_copy_20260605044855         | V-1     | 1      |                | 1
# test_store_custom_copy_20260605044855         | V-2     | 1      |                | 1
# test_store_custom_copy_20260605044855         | VI-1    | 1      |                | 1
# test_store_custom_copy_20260605044855         | VI-3    | 1      |                | 1
# test_fitness_local_brand_20260605044855       | III-2   | 1      |                | 1
# test_fitness_local_brand_20260605044855       | V-1     | 1      |                | 1
# test_fitness_local_brand_20260605044855       | V-2     | 1      |                | 1
# test_fitness_local_brand_20260605044855       | VI-1    | 1      |                | 1
# test_fitness_local_brand_20260605044855       | VI-3    | 1      |                | 1

# %% [markdown]
# ### domain_scores — aggregated per domain

# %%
q(EVAL_DB, '''
  SELECT er.job_id, ds.domain, ROUND(ds.avg_score,3) AS avg_score,
         ds.weight, ROUND(ds.weighted_contribution,3) AS weighted, ds.item_count
  FROM domain_scores ds JOIN eval_runs er ON er.eval_id = ds.eval_id
  ORDER BY er.evaluated_at DESC, ds.domain LIMIT 60
''')
# Out:
# job_id                                        | domain | avg_score | weight | weighted | item_count
# ----------------------------------------------+--------+-----------+--------+----------+-----------
# test_bespoke_florist_20260606202514           | II     | None      | 0.3    | None     | 0
# test_bespoke_florist_20260606202514           | III    | None      | 0.2    | None     | 0
# test_bespoke_florist_20260606202514           | IV     | None      | 0.3    | None     | 0
# test_bespoke_florist_20260606202514           | V      | None      | 0.1    | None     | 0
# test_store_review_event_20260605090529        | II     | None      | 0.3    | None     | 0
# test_store_review_event_20260605090529        | III    | None      | 0.2    | None     | 0
# test_store_review_event_20260605090529        | IV     | None      | 0.3    | None     | 0
# test_store_review_event_20260605090529        | V      | None      | 0.1    | None     | 0
# test_cafe_strawberry_latte_new_20260605090130 | II     | None      | 0.3    | None     | 0
# test_cafe_strawberry_latte_new_20260605090130 | III    | None      | 0.2    | None     | 0
# test_cafe_strawberry_latte_new_20260605090130 | IV     | None      | 0.3    | None     | 0
# test_cafe_strawberry_latte_new_20260605090130 | V      | None      | 0.1    | None     | 0
# test_store_custom_copy_20260605044855         | II     | None      | 0.3    | None     | 0
# test_store_custom_copy_20260605044855         | III    | None      | 0.2    | None     | 0
# test_store_custom_copy_20260605044855         | IV     | None      | 0.3    | None     | 0
# test_store_custom_copy_20260605044855         | V      | None      | 0.1    | None     | 0
# test_fitness_local_brand_20260605044855       | II     | None      | 0.3    | None     | 0
# test_fitness_local_brand_20260605044855       | III    | None      | 0.2    | None     | 0
# test_fitness_local_brand_20260605044855       | IV     | None      | 0.3    | None     | 0
# test_fitness_local_brand_20260605044855       | V      | None      | 0.1    | None     | 0

# %% [markdown]
# ### judge_status — idempotent judge queue (attempts / errors)

# %%
q(EVAL_DB, '''
  SELECT eval_id, evaluator_type, status, attempts,
         SUBSTR(COALESCE(last_error,''),1,70) AS last_error
  FROM judge_status ORDER BY rowid DESC LIMIT 40
''')
# Out:
# eval_id                               | evaluator_type | status    | attempts | last_error
# --------------------------------------+----------------+-----------+----------+-----------
# eval_55f28887cc7347ff82106008896a0d4e | human          | completed | 2        |
# eval_74caaee4b10f4ed981944eef40578069 | human          | completed | 2        |
# eval_55f28887cc7347ff82106008896a0d4e | vlm            | done      | 1        |
# eval_55f28887cc7347ff82106008896a0d4e | llm            | done      | 1        |
# eval_74caaee4b10f4ed981944eef40578069 | vlm            | done      | 1        |
# eval_74caaee4b10f4ed981944eef40578069 | llm            | done      | 1        |
